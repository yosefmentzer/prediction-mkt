# %% [markdown]
# # Overview

# %% [markdown]
# The `footystats` data set contains data related to the matches as sport events; most importantly, **goal timings**.
# The `Betfair` data set contains data related to the predictive markets associated with matches; most importantly, **odds (prices)**.
# The `footystats` data set contains only **relevant matches**, while the `Betfair` data set contains **all matches** with predictive markets for a given period of time.
# So, the natural way to merge both data sets is to find the `Betfair` `event id` for each match in the `footystats` data set.
# There is no common `key` between both data sets, so we use team names and the datetime of the match as a `key`.
#
# Objective:
# - find `Betfair` `event id` for relevant matches from `footystats` data set.
#
# Notes:
# - team names may not be the same in both data sets. Use string similarity and check manually.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
# data wrangling
import json
import numpy as np
import pandas as pd
# timezone
import pytz
# files, system
import os
# compressed files
import bz2
# processing time
from tqdm import tqdm
# string similarity
from fuzzywuzzy import fuzz
# regex
import re

# %% [markdown]
# # Get basic info for match identification (Betfair)

# %% [markdown]
# As we have ~300k Betfair match files and a maximum of ~40k are relevant for this research, we:
# 1. get only basic information for match identification from the ~300k files;
# 2. find Betfair `event id`s for relevant `footystats` matches;
# 3. process Betfair data of relevant matches alone.

# %% [markdown]
# Most matches have one `.bz2` data file, but matches can have more than one file.
# For instance, the event `27853333` has files `1.125589876.bz2` and `1.125805946.bz2`.

# %% [markdown]
# In this section, we go over all Betfair data files, get basic information on each match and store the data.

# %%
BASE_FOLDER_PATH = r'..\data\raw\betfair'

# %% [markdown]
# Function to list all `.bz2` files in the Betfair raw data folder.

# %%
def list_files(file_path, file_type):
    """
    Walks through a file path and returns all files that have the specified file type.
    
    Params:
    file_path (str): The directory to search for files in and its subdirectories.
    file_type (str): The file extension to search for (e.g. '.txt', '.pdf').
    
    Returns:
    matching_files (list): A list of filenames that have the specified file type.
    """
    matching_files = []
    for dir_path, dir_names, file_names in os.walk(file_path):
        for filename in file_names:
            if filename.lower().endswith(file_type.lower()):
                matching_files.append(os.path.join(dir_path, filename))
    return matching_files

# %%
matching_files = list_files(BASE_FOLDER_PATH, '.bz2')

# %% [markdown]
# Example of file path.

# %%
matching_files[0]
# Out:
# '..\\data\\raw\\betfair\\xds_nfs\\edp_processed\\BASIC\\2018\\Dec\\1\\28997142\\1.150836575.bz2'

# %% [markdown]
# Betfair data files are structured as one JSON/dictionary per line.
# So we store the data of one file as a list of dictionaries.
# Below is a function to get a list of dictionaries from an original compressed `.bz2` data file.

# %%
def bz2_to_dict_list(bz2_file_path):
    """Converts a .bz2 file to a list of dictionaries.
    
    Args:
        bz2_file_path (str): Path to the .bz2 file.
    
    Returns:
        list of dict: List of dictionaries represented by the .bz2 file.
    """
    with bz2.BZ2File(bz2_file_path, "rb") as bz2_file:
        data = bz2_file.read().decode("utf-8")
        data_list = []
        for line in data.splitlines():
            data_list.append(json.loads(line))
    return(data_list)

# %% [markdown]
# To define how to get match identification information, we walk through an example to check the JSON structure.

# %%
bz2_file_path = '../data/raw/betfair/xds_nfs/edp_processed/BASIC/2021/Feb/4/30263011/1.178709515.bz2'

# %%
data_list = bz2_to_dict_list(bz2_file_path)

# %% [markdown]
# The first dictionary has the information that identifies the match.

# %%
data_list[0]
# Out:
# {'op': 'mcm',
#  'clk': '2768636726',
#  'pt': 1612139881671,
#  'mc': [{'id': '1.178709515',
#    'marketDefinition': {'bspMarket': False,
#     'turnInPlayEnabled': True,
#     'persistenceEnabled': True,
#     'marketBaseRate': 5.0,
#     'eventId': '30263011',
#     'eventTypeId': '1',
#     'numberOfWinners': 1,
#     'bettingType': 'ODDS',
#     'marketType': 'MATCH_ODDS',
#     'marketTime': '2021-02-04T00:30:00.000Z',
#     'suspendTime': '2021-02-04T00:30:00.000Z',
#     'bspReconciled': False,
#     'complete': True,
#     'inPlay': False,
#     'crossMatching': True,
#     'runnersVoidable': False,
#     'numberOfActiveRunners': 3,
#     'betDelay': 0,
#     'status': 'OPEN',
#     'runners': [{'status': 'ACTIVE',
#       'sortPriority': 1,
#       'id': 198136,
#       'name': 'Corinthians'},
#      {'status': 'ACTIVE',
#       'sortPriority': 2,
#       'id': 5287019,
#       'name': 'Ceara SC Fortaleza'},
#      {'status': 'ACTIVE', 'sortPriority': 3, 'id': 58805, 'name': 'The Draw'}],
#     'regulators': ['MR_INT'],
#     'countryCode': 'BR',
#     'discountAllowed': True,
#     'timezone': 'GMT',
#     'openDate': '2021-02-04T00:30:00.000Z',
#     'version': 3604018446,
#     'name': 'Match Odds',
#     'eventName': 'Corinthians v Ceara SC Fortaleza'}}]}

# %% [markdown]
# Example: home team name

# %%
data_list[0]['mc'][0]['marketDefinition']['runners'][0]['name']
# Out:
# 'Corinthians'

# %%
data_list[0].keys()
# Out:
# dict_keys(['op', 'clk', 'pt', 'mc'])

# %% [markdown]
# After having explored the dictionary structure, we can write a function to get basic information for match identification.

# %%
EVENT_INFO_INDEX = 0
MC_INDEX = 0
HOME_TEAM_INDEX = 0
AWAY_TEAM_INDEX = 1

def get_event_basic_info(data):
    """
    Takes an event list of dictionaries and returns basic information for identification of the event.
    
    Params:
    data (list of dic): Event list of dictionaries.
    
    Returns:
    event_basic_info (dic): Basic information for identification of the event.
    """
    
    data_market_definition = data[EVENT_INFO_INDEX]['mc'][MC_INDEX]['marketDefinition']
    
    event_id = data_market_definition['eventId']
    country = data_market_definition['countryCode']
    open_date = data_market_definition['openDate']
    home_team = data_market_definition['runners'][HOME_TEAM_INDEX]['name']
    away_team = data_market_definition['runners'][AWAY_TEAM_INDEX]['name']
    event_name = data_market_definition['eventName']
    
    event_basic_info = {'event_id': event_id,
                        'country': country,
                        'open_date': open_date,
                        'home_team': home_team,
                        'away_team': away_team,
                        'event_name': event_name
                       }
    return event_basic_info

# %% [markdown]
# Function to get basic information for multiple files.

# %%
def get_event_basic_info_multiple(matching_files):
    """
    Get event basic info for multiple files as per list `matching_files`.
    Return dictionary {'file_path': event_basic_info} and list of files with reading errors.
        event_basic_info is a dictionary with basic info returned by get_event_basic_info().
    """
    event_basic_info_dic = {}
    errors_event_basic_info = {}

    for bz2_file_path in tqdm(matching_files):
        try:
            event_basic_info_dic[bz2_file_path] = get_event_basic_info(bz2_to_dict_list(bz2_file_path))
        except Exception as e:
            errors_event_basic_info[bz2_file_path] = e
    return event_basic_info_dic, errors_event_basic_info

# %% [markdown]
# Run for all files.

# %%
event_basic_info_dic, errors_event_basic_info = get_event_basic_info_multiple(matching_files)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 303894/303894 [22:17<00:00, 227.13it/s]

# %% [markdown]
# A very small number of files could not be read or had formatting issues.

# %%
len(list(errors_event_basic_info.keys())) / len(list(event_basic_info_dic.keys()))
# Out:
# 0.0004905430542066536

# %% [markdown]
# So, basic information for match identification in the Betfair data set is stored in `event_basic_info_dic`.
# Let us write it into a csv file for later reference.

# %%
EVENT_BASIC_INFO_DIC_PATH = '../data/interim/event_basic_info_dic.json'

# %%
with open(EVENT_BASIC_INFO_DIC_PATH, "w") as outfile:
    json.dump(event_basic_info_dic, outfile)

# %% [markdown]
# In case we need to load `event_basic_info_dic` from the file, the following code may be used:

# %%
with open(file=EVENT_BASIC_INFO_DIC_PATH, mode="r") as f:
    event_basic_info_dic = json.load(f)

# %% [markdown]
# # Find Betfair `event id`s for relevant footystats matches

# %% [markdown]
# Team names in Betfair and footystats may be different (e.g. Man Utd and Manchester United).
# So, we cannot directly build `keys` using team names and match datetimes.
# For each team name in the footystats data set, we define a list of compatible team names that appear in the Betfair data set.
# The lists of team names are obtained using `fuzzy` string similarity and by checking manually.
# Then, for each footystats record, we search all combinations of compatible Betfair home and away team names.
# For example:
# - footystats: `Manchester United x Manchester City, Mar 8 2020 - 4:30pm`.
# - Betfair:
#     - there are records of 'Man United' and 'Man Utd', but not 'Manchester United'.
#     - there are records of 'Manchester City' and 'Man City'.
# - Thus, we search for all 4 combinations of home and away team names, at the given match datetime.
#
# We explicitly search within the same country, as there are teams with the same name across countries (e.g. Arsenal-AR, Arsenal-GB).
# The steps are:
# - get Betfair country-team_name pairs
# - get footystats country-team_name pairs
# - for each footystats country-team_name pair, get `fuzzy` most similar Betfair team names
# - perform manual checking
# - search `event id`s

# %% [markdown]
# ## get Betfair country-team_name pairs

# %%
event_basic_info_df = pd.DataFrame(event_basic_info_dic.values())
event_basic_info_df['open_date'] = pd.to_datetime(event_basic_info_df['open_date'])
# the same match(event) may be divided into more than one data file, so remove duplicates
event_basic_info_df = event_basic_info_df.drop_duplicates()

# %%
event_basic_info_df
# Out:
#         event_id country                 open_date              home_team  \
# 0       28997142      FR 2018-12-01 16:00:00+00:00                  Lille
# 1       28997143      FR 2018-12-01 19:00:00+00:00                  Nimes
# 2       28997145      FR 2018-12-01 19:00:00+00:00                 Angers
# 3       28997146      FR 2018-12-01 19:00:00+00:00               Guingamp
# 4       28997147      FR 2018-12-01 19:00:00+00:00                 Monaco
# ...          ...     ...                       ...                    ...
# 303740  28893785      DE 2018-09-09 12:00:00+00:00  Eintracht Norderstedt
# 303741  28893786      DE 2018-09-09 13:00:00+00:00  Kieler SV Holstein II
# 303742  28893787      DE 2018-09-09 13:00:00+00:00            Wuppertaler
# 303743  28893799      GB 2018-09-09 13:00:00+00:00            South Sudan
# 303744  28893846      AR 2018-09-09 18:10:00+00:00     Argentinos Juniors
#
#                away_team                                event_name
# 0                   Lyon                              Lille v Lyon
# 1                 Amiens                            Nimes v Amiens
# 2                   Caen                             Angers v Caen
# 3                   Nice                           Guingamp v Nice
# 4            Montpellier                      Monaco v Montpellier
# ...                  ...                                       ...
# 303740          Luneburg          Eintracht Norderstedt v Luneburg
# 303741  Weiche Flensburg  Kieler SV Holstein II v Weiche Flensburg
# 303742  Alemannia Aachen            Wuppertaler v Alemannia Aachen
# 303743              Mali                        South Sudan v Mali
# 303744      CA Temperley         Argentinos Juniors v CA Temperley
#
# [273063 rows x 6 columns]

# %% [markdown]
# Let us check the distribution of column `country`.

# %%
event_basic_info_df['country'].value_counts()
# Out:
# GB    61979
# ES    41274
# BR    28395
# DE    24077
# IT    19284
# AR    16556
# FR    12270
# PT    11415
# IL    10177
# JP     9934
# RU     9532
# TR     7975
# NL     7801
# US     7333
# CN     2729
# AU     1594
# CA      709
# RO        3
# BY        2
# CM        2
# AM        2
# AO        2
# AG        2
# UZ        2
# UY        1
# NO        1
# AD        1
# VE        1
# BZ        1
# AW        1
# IS        1
# IE        1
# TN        1
# BA        1
# BT        1
# AT        1
# EC        1
# MA        1
# Name: country, dtype: int64

# %% [markdown]
# There is a very small number of events in countries other than the list of relevant countries.
# Let us enforce the list of countries.

# %%
COUNTRY_CODES_PATH = '../betfair-api/configuration/countryCodes.csv'
country_codes = list(pd.read_csv(COUNTRY_CODES_PATH)['marketDefinition.countryCode'].values)
event_basic_info_df = event_basic_info_df[event_basic_info_df['country'].isin(country_codes)].copy()

# %%
event_basic_info_df
# Out:
#         event_id country                 open_date              home_team  \
# 0       28997142      FR 2018-12-01 16:00:00+00:00                  Lille
# 1       28997143      FR 2018-12-01 19:00:00+00:00                  Nimes
# 2       28997145      FR 2018-12-01 19:00:00+00:00                 Angers
# 3       28997146      FR 2018-12-01 19:00:00+00:00               Guingamp
# 4       28997147      FR 2018-12-01 19:00:00+00:00                 Monaco
# ...          ...     ...                       ...                    ...
# 303740  28893785      DE 2018-09-09 12:00:00+00:00  Eintracht Norderstedt
# 303741  28893786      DE 2018-09-09 13:00:00+00:00  Kieler SV Holstein II
# 303742  28893787      DE 2018-09-09 13:00:00+00:00            Wuppertaler
# 303743  28893799      GB 2018-09-09 13:00:00+00:00            South Sudan
# 303744  28893846      AR 2018-09-09 18:10:00+00:00     Argentinos Juniors
#
#                away_team                                event_name
# 0                   Lyon                              Lille v Lyon
# 1                 Amiens                            Nimes v Amiens
# 2                   Caen                             Angers v Caen
# 3                   Nice                           Guingamp v Nice
# 4            Montpellier                      Monaco v Montpellier
# ...                  ...                                       ...
# 303740          Luneburg          Eintracht Norderstedt v Luneburg
# 303741  Weiche Flensburg  Kieler SV Holstein II v Weiche Flensburg
# 303742  Alemannia Aachen            Wuppertaler v Alemannia Aachen
# 303743              Mali                        South Sudan v Mali
# 303744      CA Temperley         Argentinos Juniors v CA Temperley
#
# [273034 rows x 6 columns]

# %% [markdown]
# Betfair records the country where a match took place, whereas footystats' `country` is the country of the *league*.
# So, matches played in Canada for the Major League Soccer (US) will be recorded as `CA` in Betfair and `US` in footystats.
# In the opposite direction, Betfair records as `GB` all matches played in Great Britain (e.g. English, Scottish leagues).
# We deal with `GB` later on, when we process footystats data.
# Now, get a column in which matches played in Canada show up as `US`.

# %%
event_basic_info_df['country_caus'] = event_basic_info_df['country'].replace('CA', 'US')

# %%
event_basic_info_df
# Out:
#         event_id country                 open_date              home_team  \
# 0       28997142      FR 2018-12-01 16:00:00+00:00                  Lille
# 1       28997143      FR 2018-12-01 19:00:00+00:00                  Nimes
# 2       28997145      FR 2018-12-01 19:00:00+00:00                 Angers
# 3       28997146      FR 2018-12-01 19:00:00+00:00               Guingamp
# 4       28997147      FR 2018-12-01 19:00:00+00:00                 Monaco
# ...          ...     ...                       ...                    ...
# 303740  28893785      DE 2018-09-09 12:00:00+00:00  Eintracht Norderstedt
# 303741  28893786      DE 2018-09-09 13:00:00+00:00  Kieler SV Holstein II
# 303742  28893787      DE 2018-09-09 13:00:00+00:00            Wuppertaler
# 303743  28893799      GB 2018-09-09 13:00:00+00:00            South Sudan
# 303744  28893846      AR 2018-09-09 18:10:00+00:00     Argentinos Juniors
#
#                away_team                                event_name  \
# 0                   Lyon                              Lille v Lyon
# 1                 Amiens                            Nimes v Amiens
# 2                   Caen                             Angers v Caen
# 3                   Nice                           Guingamp v Nice
# 4            Montpellier                      Monaco v Montpellier
# ...                  ...                                       ...
# 303740          Luneburg          Eintracht Norderstedt v Luneburg
# 303741  Weiche Flensburg  Kieler SV Holstein II v Weiche Flensburg
# 303742  Alemannia Aachen            Wuppertaler v Alemannia Aachen
# 303743              Mali                        South Sudan v Mali
# 303744      CA Temperley         Argentinos Juniors v CA Temperley
#
#        country_caus
# 0                FR
# 1                FR
# 2                FR
# 3                FR
# 4                FR
# ...             ...
# 303740           DE
# 303741           DE
# 303742           DE
# 303743           GB
# 303744           AR
#
# [273034 rows x 7 columns]

# %% [markdown]
# We now exclude matches that are obviously not relevant to this research, such as womens' matches, under 23, 'young', 'reserves'.

# %%
check_strings = [' (W)', 'U19', 'U20', 'U21', 'U23', ' (Y)', ' (Res)']
escaped_check_strings = [re.escape(s) for s in check_strings]
mask = ~event_basic_info_df['event_name'].str.contains('|'.join(escaped_check_strings), regex=True)
event_basic_info_df = event_basic_info_df[mask]
event_basic_info_df
# Out:
#         event_id country                 open_date              home_team  \
# 0       28997142      FR 2018-12-01 16:00:00+00:00                  Lille
# 1       28997143      FR 2018-12-01 19:00:00+00:00                  Nimes
# 2       28997145      FR 2018-12-01 19:00:00+00:00                 Angers
# 3       28997146      FR 2018-12-01 19:00:00+00:00               Guingamp
# 4       28997147      FR 2018-12-01 19:00:00+00:00                 Monaco
# ...          ...     ...                       ...                    ...
# 303740  28893785      DE 2018-09-09 12:00:00+00:00  Eintracht Norderstedt
# 303741  28893786      DE 2018-09-09 13:00:00+00:00  Kieler SV Holstein II
# 303742  28893787      DE 2018-09-09 13:00:00+00:00            Wuppertaler
# 303743  28893799      GB 2018-09-09 13:00:00+00:00            South Sudan
# 303744  28893846      AR 2018-09-09 18:10:00+00:00     Argentinos Juniors
#
#                away_team                                event_name  \
# 0                   Lyon                              Lille v Lyon
# 1                 Amiens                            Nimes v Amiens
# 2                   Caen                             Angers v Caen
# 3                   Nice                           Guingamp v Nice
# 4            Montpellier                      Monaco v Montpellier
# ...                  ...                                       ...
# 303740          Luneburg          Eintracht Norderstedt v Luneburg
# 303741  Weiche Flensburg  Kieler SV Holstein II v Weiche Flensburg
# 303742  Alemannia Aachen            Wuppertaler v Alemannia Aachen
# 303743              Mali                        South Sudan v Mali
# 303744      CA Temperley         Argentinos Juniors v CA Temperley
#
#        country_caus
# 0                FR
# 1                FR
# 2                FR
# 3                FR
# 4                FR
# ...             ...
# 303740           DE
# 303741           DE
# 303742           DE
# 303743           GB
# 303744           AR
#
# [235074 rows x 7 columns]

# %% [markdown]
# We can now get team names.

# %%
bf_home_team_names = event_basic_info_df[['country_caus', 'home_team']].rename(columns={'home_team': 'team_name'})
bf_away_team_names = event_basic_info_df[['country_caus', 'away_team']].rename(columns={'away_team': 'team_name'})
bf_team_names = pd.concat([bf_home_team_names, bf_away_team_names]).drop_duplicates().reset_index().drop(columns=['index'])
bf_team_names
# Out:
#       country_caus               team_name
# 0               FR                   Lille
# 1               FR                   Nimes
# 2               FR                  Angers
# 3               FR                Guingamp
# 4               FR                  Monaco
# ...            ...                     ...
# 12661           DE                    Peru
# 12662           DE  Eintracht Braunschweig
# 12663           DE              Heeslinger
# 12664           JP          Sfida Setagaya
# 12665           PT             GD Trancoso
#
# [12666 rows x 2 columns]

# %% [markdown]
# Export

# %%
BF_TEAM_NAMES_PATH = '../data/interim/bf_team_names.csv'

# %%
bf_team_names.to_csv(BF_TEAM_NAMES_PATH, index=False)

# %% [markdown]
# ## get footystats country-team_name pairs

# %%
FOOTYSTATS_FILEPATH = '../data/interim/footy.csv'

# %%
footy = pd.read_csv(FOOTYSTATS_FILEPATH, parse_dates=['date_GMT'])

# %%
footy
# Out:
#         timestamp            date_GMT    status      home_team_name  \
# 0      1430589600 2015-05-02 18:00:00  complete              Olimpo
# 1      1430597700 2015-05-02 20:15:00  complete   Gimnasia La Plata
# 2      1430601000 2015-05-02 21:10:00  complete         San Lorenzo
# 3      1430605800 2015-05-02 22:30:00  complete  Argentinos Juniors
# 4      1430608500 2015-05-02 23:15:00  complete         Racing Club
# ...           ...                 ...       ...                 ...
# 36081  1583632800 2020-03-08 02:00:00  complete     Colorado Rapids
# 36082  1583636400 2020-03-08 03:00:00  complete           LA Galaxy
# 36083  1583636400 2020-03-08 03:00:00  complete    Seattle Sounders
# 36084  1583708400 2020-03-08 23:00:00  complete    Portland Timbers
# 36085  1583721000 2020-03-09 02:30:00  complete      Los Angeles FC
#
#             away_team_name  home_team_goal_count  away_team_goal_count  \
# 0              Estudiantes                     0                     0
# 1        Newell's Old Boys                     0                     0
# 2          Vélez Sarsfield                     1                     0
# 3                 Aldosivi                     0                     1
# 4                    Lanús                     2                     0
# ...                    ...                   ...                   ...
# 36081         Orlando City                     2                     1
# 36082  Vancouver Whitecaps                     0                     1
# 36083        Columbus Crew                     1                     1
# 36084         Nashville SC                     1                     0
# 36085   Philadelphia Union                     3                     3
#
#       home_team_goal_timings away_team_goal_timings    country
# 0                        NaN                    NaN  argentina
# 1                        NaN                    NaN  argentina
# 2                         83                    NaN  argentina
# 3                        NaN                   45'1  argentina
# 4                      72,90                    NaN  argentina
# ...                      ...                    ...        ...
# 36081                  64,90                     82        usa
# 36082                    NaN                     74        usa
# 36083                     79                     33        usa
# 36084                     12                    NaN        usa
# 36085               38,49,71               29,48,69        usa
#
# [36086 rows x 10 columns]

# %% [markdown]
# Get country codes, taking into consideration that English and Scottish leagues are recorded as `GB` in Betfair.

# %%
FOOTY_COUNTRY_CODES_PATH = 'configuration/footy_country_codes.csv'
footy_country_codes = pd.read_csv(FOOTY_COUNTRY_CODES_PATH)
footy_country_codes
# Out:
#    country_name country_code
# 0     argentina           AR
# 1     australia           AU
# 2        brazil           BR
# 3         china           CN
# 4       england           GB
# 5        france           FR
# 6       germany           DE
# 7        israel           IL
# 8         italy           IT
# 9         japan           JP
# 10  netherlands           NL
# 11     portugal           PT
# 12       russia           RU
# 13     scotland           GB
# 14        spain           ES
# 15       turkey           TR
# 16          usa           US

# %%
footy = footy.merge(footy_country_codes, 
                    how='left', 
                    left_on='country', 
                    right_on='country_name').drop(columns=['country_name'])

# %%
footy
# Out:
#         timestamp            date_GMT    status      home_team_name  \
# 0      1430589600 2015-05-02 18:00:00  complete              Olimpo
# 1      1430597700 2015-05-02 20:15:00  complete   Gimnasia La Plata
# 2      1430601000 2015-05-02 21:10:00  complete         San Lorenzo
# 3      1430605800 2015-05-02 22:30:00  complete  Argentinos Juniors
# 4      1430608500 2015-05-02 23:15:00  complete         Racing Club
# ...           ...                 ...       ...                 ...
# 36081  1583632800 2020-03-08 02:00:00  complete     Colorado Rapids
# 36082  1583636400 2020-03-08 03:00:00  complete           LA Galaxy
# 36083  1583636400 2020-03-08 03:00:00  complete    Seattle Sounders
# 36084  1583708400 2020-03-08 23:00:00  complete    Portland Timbers
# 36085  1583721000 2020-03-09 02:30:00  complete      Los Angeles FC
#
#             away_team_name  home_team_goal_count  away_team_goal_count  \
# 0              Estudiantes                     0                     0
# 1        Newell's Old Boys                     0                     0
# 2          Vélez Sarsfield                     1                     0
# 3                 Aldosivi                     0                     1
# 4                    Lanús                     2                     0
# ...                    ...                   ...                   ...
# 36081         Orlando City                     2                     1
# 36082  Vancouver Whitecaps                     0                     1
# 36083        Columbus Crew                     1                     1
# 36084         Nashville SC                     1                     0
# 36085   Philadelphia Union                     3                     3
#
#       home_team_goal_timings away_team_goal_timings    country country_code
# 0                        NaN                    NaN  argentina           AR
# 1                        NaN                    NaN  argentina           AR
# 2                         83                    NaN  argentina           AR
# 3                        NaN                   45'1  argentina           AR
# 4                      72,90                    NaN  argentina           AR
# ...                      ...                    ...        ...          ...
# 36081                  64,90                     82        usa           US
# 36082                    NaN                     74        usa           US
# 36083                     79                     33        usa           US
# 36084                     12                    NaN        usa           US
# 36085               38,49,71               29,48,69        usa           US
#
# [36086 rows x 11 columns]

# %%
footy_home_team_names = footy[['country_code', 'home_team_name']].rename(columns={'home_team_name': 'team_name'})
footy_away_team_names = footy[['country_code', 'away_team_name']].rename(columns={'away_team_name': 'team_name'})
footy_team_names = pd.concat([footy_home_team_names, footy_away_team_names]).drop_duplicates().reset_index().drop(columns=['index'])
footy_team_names = footy_team_names.sort_values(['country_code', 'team_name'])
footy_team_names
# Out:
#     country_code            team_name
# 21            AR             Aldosivi
# 3             AR   Argentinos Juniors
# 11            AR              Arsenal
# 6             AR     Atlético Rafaela
# 31            AR     Atlético Tucumán
# ..           ...                  ...
# 530           US       SJ Earthquakes
# 531           US     Seattle Sounders
# 519           US          Sporting KC
# 528           US              Toronto
# 525           US  Vancouver Whitecaps
#
# [539 rows x 2 columns]

# %%
FOOTY_TEAM_NAMES_PATH = '../data/interim/footy_team_names.csv'

# %%
footy_team_names.to_csv(FOOTY_TEAM_NAMES_PATH, index=False)

# %% [markdown]
# ## get `fuzzy` most similar Betfair team names

# %% [markdown]
# The following function takes the DataFrames with countries and team names that we got in the previous sections, and returns the `n` most similar Betfair team names and scores for each footystats team name.

# %%
def get_similar_teams(footy_team_names, bf_team_names, n=3):
    """
    Given two pandas DataFrames with countries and team names, return the n most similar team names from the second list 
    in the same country, for each team name in the first list, along with the string similarity score.
    
    :param footy_team_names: DataFrame of countries and team names from footystats
    :param bf_team_names: DataFrame of countries and team names from Betfair
    :param n: the number of most similar teams to return
    :return: a dictionary mapping each pair country-footy team name to a list of n tuples, 
            where each tuple contains a team name from betfair_team_names and its similarity score to the footy team name
    """
    result = {}
    for country_code, footy_team in tqdm(zip(footy_team_names['country_code'], footy_team_names['team_name'])):
        scores = []
        for betfair_team in bf_team_names[bf_team_names['country_caus'] == country_code]['team_name']:
            scores.append((betfair_team, fuzz.ratio(footy_team, betfair_team)))
        scores = sorted(scores, key=lambda x: x[1], reverse=True)[:n]
        result[(country_code, footy_team)] = scores
    return result

# %% [markdown]
# We run the function with `n=13`. This is not a 'magic number', but the result of an iteractive process with the next acticity, the manual checking step.
# For most teams, the first or second most similar team names suffice, but we surprisingly get relevant names at lower ranks for a non-negligible minority of teams.

# %%
similar_team_names = get_similar_teams(footy_team_names, bf_team_names, n=13)
# Out:
# 539it [00:07, 68.32it/s]

# %%
footy_team_names_scores = footy_team_names.copy()
footy_team_names_scores['scores'] = [similar_team_names[(country_code, footy_team)] 
                                     for (country_code, footy_team)
                                     in zip(footy_team_names['country_code'], footy_team_names['team_name'])]
footy_team_names_scores
# Out:
#     country_code            team_name  \
# 21            AR             Aldosivi
# 3             AR   Argentinos Juniors
# 11            AR              Arsenal
# 6             AR     Atlético Rafaela
# 31            AR     Atlético Tucumán
# ..           ...                  ...
# 530           US       SJ Earthquakes
# 531           US     Seattle Sounders
# 519           US          Sporting KC
# 528           US              Toronto
# 525           US  Vancouver Whitecaps
#
#                                                 scores
# 21   [(Aldosivi, 100), (Altos, 62), (CA Aldosivi Re...
# 3    [(Argentinos Juniors, 100), (Argentinos Junior...
# 11   [(Arsenal FC, 82), (Arenas, 77), (Argentina, 6...
# 6    [(Atletico Rafaela, 94), (Atletico Parana, 71)...
# 31   [(Atletico Tucuman, 88), (Club Atletico Tucuma...
# ..                                                 ...
# 530  [(San Jose Earthquakes, 82), (San Jose Earthqu...
# 531  [(Seattle Sounders, 100), (Seattle Sounders 2,...
# 519  [(Sporting Kansas, 77), (Sporting Orlando, 67)...
# 528  [(Toronto FC, 82), (Toronto FC II, 70), (Toron...
# 525  [(Vancouver Whitecaps, 100), (Vancouver Whitec...
#
# [539 rows x 3 columns]

# %% [markdown]
# Explode the `scores` column to prepare a DataFrame to be used in the manual checking step.

# %%
footy_team_names_scores_exploded = pd.concat([footy_team_names_scores, 
                                              pd.concat([footy_team_names_scores['scores'].apply(pd.Series)[col].apply(pd.Series) for col in range(0, 13)], 
                                                        axis=1)], 
                                             axis=1).drop(columns=['scores'])
footy_team_names_scores_exploded
# Out:
#     country_code            team_name                     0    1  \
# 21            AR             Aldosivi              Aldosivi  100
# 3             AR   Argentinos Juniors    Argentinos Juniors  100
# 11            AR              Arsenal            Arsenal FC   82
# 6             AR     Atlético Rafaela      Atletico Rafaela   94
# 31            AR     Atlético Tucumán      Atletico Tucuman   88
# ..           ...                  ...                   ...  ...
# 530           US       SJ Earthquakes  San Jose Earthquakes   82
# 531           US     Seattle Sounders      Seattle Sounders  100
# 519           US          Sporting KC       Sporting Kansas   77
# 528           US              Toronto            Toronto FC   82
# 525           US  Vancouver Whitecaps   Vancouver Whitecaps  100
#
#                            0   1                        0   1  \
# 21                     Altos  62     CA Aldosivi Reserves  57
# 3     Argentinos Juniors Res  90           Argentinos Jrs  88
# 11                    Arenas  77                Argentina  62
# 6            Atletico Parana  71         Atletico Campana  69
# 31     Club Atletico Tucuman  76              Atl Tucuman  74
# ..                       ...  ..                      ...  ..
# 530  San Jose Earthquakes II  76               Martinique  50
# 531       Seattle Sounders 2  94      Seattle Sounders II  91
# 519         Sporting Orlando  67  Sporting Kansas City II  65
# 528            Toronto FC II  70          Toronto Croatia  64
# 525   Vancouver Whitecaps II  93            Vancouver Utd  69
#
#                                0   1  ...                      0   1  \
# 21                       Bolivia  53  ...         Arg de Rosario  45
# 3    Argentinos Juniors Reserves  80  ...        Argentino Merlo  67
# 11              Arsenal FC (Arg)  61  ...            CA Penaflor  56
# 6                  Atletico Raci  69  ...        Atletico Cuyaya  65
# 31              Atletico Campana  62  ...            Atletico MG  59
# ..                           ...  ..  ...                    ...  ..
# 530                      Schalke  48  ...     Johor Darul Takzim  44
# 531       Seattle Sounders FC II  84  ...         OSA Seattle FC  53
# 519         Khalsa Sporting Club  65  ...  Wayne County Sporting  50
# 528                   Tormenta 2  59  ...             Burlington  47
# 525       Vancouver Thunderbirds  63  ...     Southern States SC  43
#
#                             0   1                        0   1  \
# 21                 CA Florida  44              El Porvenir  42
# 3                   Argentino  67             Argentino MM  67
# 11                CA Regional  56      CA Barracas Central  54
# 6         Atletico Marquesado  63  CA 9 de Julio (Rafaela)  62
# 31            Atletico Parana  58          Atletico Cuyaya  58
# ..                        ...  ..                      ...  ..
# 530    Santa Cruz Breakers FC  44       Santa Cruz Breaker  44
# 531   Golden State Misioneros  51         Real Monarchs SL  50
# 519                 Austin FC  50            Fort Wayne FC  50
# 528                Cotonsport  47               Fiorentina  47
# 525  Seacoast United Phantoms  42           Lane United FC  42
#
#                           0   1                      0   1
# 21                  Almagro  40                Rosario  40
# 3       Argentino Pergamino  65   Argentino Monte Maiz  63
# 11             Ros. Central  53       Barracas Central  52
# 6      Club Atletico Parana  61                Rafaela  61
# 31      Atletico Camioneros  57    Atletico Concepcion  57
# ..                      ...  ..                    ...  ..
# 530  Fort Worth Vaqueros FC  44         Real Salt Lake  43
# 531        Oakland Stompers  50  Western Mass Pioneers  49
# 519               Boston FC  50          Floridians FC  50
# 528                  Dragon  46            El Farolito  44
# 525    San Jose Earthquakes  41   Southern C Seahorses  41
#
# [539 rows x 28 columns]

# %%
# get column names
cols = ['country_code', 'team_name']
for i in range(13):
    cols.append(f'bf_team{i+1}')
    cols.append(f'score{i+1}')

# %%
footy_team_names_scores_exploded.columns = cols
footy_team_names_scores_exploded
# Out:
#     country_code            team_name              bf_team1  score1  \
# 21            AR             Aldosivi              Aldosivi     100
# 3             AR   Argentinos Juniors    Argentinos Juniors     100
# 11            AR              Arsenal            Arsenal FC      82
# 6             AR     Atlético Rafaela      Atletico Rafaela      94
# 31            AR     Atlético Tucumán      Atletico Tucuman      88
# ..           ...                  ...                   ...     ...
# 530           US       SJ Earthquakes  San Jose Earthquakes      82
# 531           US     Seattle Sounders      Seattle Sounders     100
# 519           US          Sporting KC       Sporting Kansas      77
# 528           US              Toronto            Toronto FC      82
# 525           US  Vancouver Whitecaps   Vancouver Whitecaps     100
#
#                     bf_team2  score2                 bf_team3  score3  \
# 21                     Altos      62     CA Aldosivi Reserves      57
# 3     Argentinos Juniors Res      90           Argentinos Jrs      88
# 11                    Arenas      77                Argentina      62
# 6            Atletico Parana      71         Atletico Campana      69
# 31     Club Atletico Tucuman      76              Atl Tucuman      74
# ..                       ...     ...                      ...     ...
# 530  San Jose Earthquakes II      76               Martinique      50
# 531       Seattle Sounders 2      94      Seattle Sounders II      91
# 519         Sporting Orlando      67  Sporting Kansas City II      65
# 528            Toronto FC II      70          Toronto Croatia      64
# 525   Vancouver Whitecaps II      93            Vancouver Utd      69
#
#                         bf_team4  score4  ...               bf_team9  score9  \
# 21                       Bolivia      53  ...         Arg de Rosario      45
# 3    Argentinos Juniors Reserves      80  ...        Argentino Merlo      67
# 11              Arsenal FC (Arg)      61  ...            CA Penaflor      56
# 6                  Atletico Raci      69  ...        Atletico Cuyaya      65
# 31              Atletico Campana      62  ...            Atletico MG      59
# ..                           ...     ...  ...                    ...     ...
# 530                      Schalke      48  ...     Johor Darul Takzim      44
# 531       Seattle Sounders FC II      84  ...         OSA Seattle FC      53
# 519         Khalsa Sporting Club      65  ...  Wayne County Sporting      50
# 528                   Tormenta 2      59  ...             Burlington      47
# 525       Vancouver Thunderbirds      63  ...     Southern States SC      43
#
#                     bf_team10  score10                bf_team11  score11  \
# 21                 CA Florida       44              El Porvenir       42
# 3                   Argentino       67             Argentino MM       67
# 11                CA Regional       56      CA Barracas Central       54
# 6         Atletico Marquesado       63  CA 9 de Julio (Rafaela)       62
# 31            Atletico Parana       58          Atletico Cuyaya       58
# ..                        ...      ...                      ...      ...
# 530    Santa Cruz Breakers FC       44       Santa Cruz Breaker       44
# 531   Golden State Misioneros       51         Real Monarchs SL       50
# 519                 Austin FC       50            Fort Wayne FC       50
# 528                Cotonsport       47               Fiorentina       47
# 525  Seacoast United Phantoms       42           Lane United FC       42
#
#                   bf_team12  score12              bf_team13  score13
# 21                  Almagro       40                Rosario       40
# 3       Argentino Pergamino       65   Argentino Monte Maiz       63
# 11             Ros. Central       53       Barracas Central       52
# 6      Club Atletico Parana       61                Rafaela       61
# 31      Atletico Camioneros       57    Atletico Concepcion       57
# ..                      ...      ...                    ...      ...
# 530  Fort Worth Vaqueros FC       44         Real Salt Lake       43
# 531        Oakland Stompers       50  Western Mass Pioneers       49
# 519               Boston FC       50          Floridians FC       50
# 528                  Dragon       46            El Farolito       44
# 525    San Jose Earthquakes       41   Southern C Seahorses       41
#
# [539 rows x 28 columns]

# %% [markdown]
# The DataFrame is exported to be used in the manual checking step.

# %%
FOOTY_TEAM_NAMES_SCORES_EXPLODED_PATH = '../data/interim/footy_team_names_scores_exploded.csv'

# %%
footy_team_names_scores_exploded.to_csv(FOOTY_TEAM_NAMES_SCORES_EXPLODED_PATH, index=False)

# %% [markdown]
# ## manual checking

# %% [markdown]
# The team names were checked manually and the mapping of footystats team names to Betfair team names is stored in the file `team_names_manual_check.csv`.
# The process was not performed at once.
# Feedback from the number of matches with Betfair data per team was used to identify teams with former names or aliases.

# %%
TEAM_NAMES_MANUAL_CHECK_PATH = '../data/interim/team_names_manual_check.csv'

# %%
team_names_manual_check = pd.read_csv(TEAM_NAMES_MANUAL_CHECK_PATH).drop(columns=['Column1'])
team_names_manual_check
# Out:
#       row_type country_code            team_name             bf_team1  score1  \
# 0        teams           AR             Aldosivi             Aldosivi     100
# 1     zero_one           AR             Aldosivi                    1     100
# 2        teams           AR   Argentinos Juniors   Argentinos Juniors     100
# 3     zero_one           AR   Argentinos Juniors                    1     100
# 4        teams           AR              Arsenal           Arsenal FC      82
# ...        ...          ...                  ...                  ...     ...
# 1073  zero_one           US          Sporting KC                    1      77
# 1074     teams           US              Toronto           Toronto FC      82
# 1075  zero_one           US              Toronto                    1      82
# 1076     teams           US  Vancouver Whitecaps  Vancouver Whitecaps     100
# 1077  zero_one           US  Vancouver Whitecaps                    1     100
#
#                     bf_team2  score2              bf_team3  score3  \
# 0                      Altos      62  CA Aldosivi Reserves      57
# 1                          0      62                     0      57
# 2     Argentinos Juniors Res      90        Argentinos Jrs      88
# 3                          0      90                     1      88
# 4                     Arenas      77             Argentina      62
# ...                      ...     ...                   ...     ...
# 1073                       0      67                     0      65
# 1074           Toronto FC II      70       Toronto Croatia      64
# 1075                       0      70                     0      64
# 1076  Vancouver Whitecaps II      93         Vancouver Utd      69
# 1077                       0      93                     0      69
#
#                          bf_team4  ...  score9                 bf_team10  \
# 0                         Bolivia  ...      45                CA Florida
# 1                               0  ...      45                         0
# 2     Argentinos Juniors Reserves  ...      67                 Argentino
# 3                               0  ...      67                         0
# 4                Arsenal FC (Arg)  ...      56               CA Regional
# ...                           ...  ...     ...                       ...
# 1073                            0  ...      50                         0
# 1074                   Tormenta 2  ...      47                Cotonsport
# 1075                            0  ...      47                         0
# 1076       Vancouver Thunderbirds  ...      43  Seacoast United Phantoms
# 1077                            0  ...      43                         0
#
#       score10            bf_team11  score11             bf_team12  score12  \
# 0          44          El Porvenir       42               Almagro       40
# 1          44                    0       42                     0       40
# 2          67         Argentino MM       67   Argentino Pergamino       65
# 3          67                    0       67                     0       65
# 4          56  CA Barracas Central       54          Ros. Central       53
# ...       ...                  ...      ...                   ...      ...
# 1073       50                    0       50                     0       50
# 1074       47           Fiorentina       47                Dragon       46
# 1075       47                    0       47                     0       46
# 1076       42       Lane United FC       42  San Jose Earthquakes       41
# 1077       42                    0       42                     0       41
#
#                  bf_team13  score13 manual_insertion
# 0                  Rosario       40              NaN
# 1                        0       40                0
# 2     Argentino Monte Maiz       63              NaN
# 3                        0       63                0
# 4         Barracas Central       52              NaN
# ...                    ...      ...              ...
# 1073                     0       50                1
# 1074           El Farolito       44              NaN
# 1075                     0       44                0
# 1076  Southern C Seahorses       41              NaN
# 1077                     0       41                0
#
# [1078 rows x 30 columns]

# %% [markdown]
# Row types are alternate. For columns `bf_team{i}`, `teams` rows contain team names, and `zero_one` rows contain Booleans representing the relevance of `bf_team{i}` for the respective footystats `team_name`.
# This structure was convenient for manual checking, but we separate them here so we can work programatically.

# %%
teams = team_names_manual_check[team_names_manual_check['row_type'] == 'teams']
zero_one = team_names_manual_check[team_names_manual_check['row_type'] == 'zero_one']

# %%
# columns with bf team names
bf_team_cols = [f'bf_team{i+1}' for i in range(13)]
bf_team_cols.append('manual_insertion')

team_names_mapping = {}

# get list of relevant bf team names per footy team
for i, (country_code, team_name) in enumerate(zip(teams['country_code'], teams['team_name'])):
    team_names_mapping[(country_code, team_name)] = list(np.array(teams[bf_team_cols])[i, :][np.array(zero_one[bf_team_cols]).astype(int).astype(bool)[i, :]])

# %% [markdown]
# team_names_mapping: {(country, footy_team_name): [bf_team_name1, bf_team_name2, ...]}

# %%
team_names_mapping
# Out:
# {('AR', 'Aldosivi'): ['Aldosivi'],
#  ('AR', 'Argentinos Juniors'): ['Argentinos Juniors',
#   'Argentinos Jrs',
#   'Arg Juniors'],
#  ('AR', 'Arsenal'): ['Arsenal FC', 'Arsenal FC (Arg)', 'Arsenal De Sarandi'],
#  ('AR', 'Atlético Rafaela'): ['Atletico Rafaela', 'Rafaela'],
#  ('AR', 'Atlético Tucumán'): ['Atletico Tucuman',
#   'Club Atletico Tucuman',
#   'Atl Tucuman'],
#  ('AR', 'Banfield'): ['Banfield'],
#  ('AR', 'Belgrano'): ['Belgrano'],
#  ('AR', 'Boca Juniors'): ['Boca Juniors'],
#  ('AR', 'Central Córdoba SdE'): ['Central Cordoba (SdE)',
#   'Central Cordoba',
#   'CA Central Cordoba',
#   'Cordoba (SdE)',
#   'C Cordoba'],
#  ('AR', 'Chacarita Juniors'): ['Chacarita'],
#  ('AR', 'Colón'): ['Colon'],
#  ('AR', 'Crucero del Norte'): ['Crucero del Norte',
#   'Crucero del N',
#   'CM Crucero del N',
#   'Club Mutual Crucero del Norte',
#   'CMC del Norte',
#   'Club Mutual Crucero del Nor',
#   'Club Mutual Crucero del No',
#   'Club Mutual Crucero del ',
#   'Crucero',
#   'Club Mutual Crucero del'],
#  ('AR', 'Defensa y Justicia'): ['Defensa y Justicia',
#   'Defensa Justicia',
#   'Def y Justicia',
#   'Defensa'],
#  ('AR', 'Estudiantes'): ['Estudiantes'],
#  ('AR', 'Gimnasia La Plata'): ['Gimnasia La Plata',
#   'Gim La Plata',
#   'Gimnasia Lp',
#   'Gimnasia'],
#  ('AR', 'Godoy Cruz'): ['Godoy Cruz'],
#  ('AR', 'Huracán'): ['Huracan'],
#  ('AR', 'Independiente'): ['Independiente', 'CA Independiente'],
#  ('AR', 'Lanús'): ['Lanus'],
#  ('AR', "Newell's Old Boys"): ['Newells'],
#  ('AR', 'Nueva Chicago'): ['Nueva Chicago'],
#  ('AR', 'Olimpo'): ['Olimpo'],
#  ('AR', 'Patronato'): ['Patronato'],
#  ('AR', 'Quilmes'): ['Quilmes'],
#  ('AR', 'Racing Club'): ['Racing Club'],
#  ('AR', 'River Plate'): ['River Plate'],
#  ('AR', 'Rosario Central'): ['Rosario Central',
#   'Rosario Centr',
#   'Rosario Cen',
#   'Ros. Central',
#   'Rosario'],
#  ('AR', 'San Lorenzo'): ['San Lorenzo', 'CA San Lorenzo'],
#  ('AR', 'San Martín San Juan'): ['San Martin San Juan',
#   'San Martin de San Juan',
#   'San Martin SJ',
#   'San Martin'],
#  ('AR', 'San Martín Tucumán'): ['San Martin de Tucuman',
#   'San Martin de Tucman',
#   'San Martin de Tuc',
#   'San M de Tucuman',
#   'San Martin'],
#  ('AR', 'Sarmiento'): ['Sarmiento', 'CA Sarmiento', 'Sarmiento de Junin'],
#  ('AR', 'Talleres Córdoba'): ['Talleres de Cordoba',
#   'Talleres',
#   'Club Atletico Talleres'],
#  ('AR', 'Temperley'): ['CA Temperley'],
#  ('AR', 'Tigre'): ['Tigre'],
#  ('AR', 'Unión Santa Fe'): ['Union Santa Fe', 'Santa Fe'],
#  ('AR', 'Vélez Sarsfield'): ['Velez Sarsfield', 'Velez'],
#  ('AU', 'Adelaide United'): ['Adelaide United', 'Adelaide'],
#  ('AU', 'Brisbane Roar'): ['Brisbane Roar', 'Brisbane'],
#  ('AU', 'Central Coast Mariners'): ['Central Coast Mariners', 'Central Coast'],
#  ('AU', 'Melbourne City FC'): ['Melbourne City'],
#  ('AU', 'Melbourne Victory FC'): ['Melbourne Victory FC', 'Melbourne Victory'],
#  ('AU', 'Newcastle Jets FC'): ['Newcastle Jets FC',
#   'Newcastle Jets',
#   'Newcastle'],
#  ('AU', 'Perth Glory FC'): ['Perth Glory', 'Perth'],
#  ('AU', 'Sydney FC'): ['Sydney FC', 'Sydney'],
#  ('AU', 'Wellington Phoenix'): ['Wellington Phoenix',
#   'Wellington Poenix',
#   'Wellington'],
#  ('AU', 'Western Sydney Wanderers'): ['Western Sydney Wanderers',
#   'Western Sydney'],
#  ('AU', 'Western United'): ['Western United'],
#  ('BR', 'América Mineiro'): ['America MG', 'America Futebol Clube'],
#  ('BR', 'Atlético GO'): ['Atletico Go', 'Atletico Goianiense'],
#  ('BR', 'Atlético Mineiro'): ['Atletico Mineiro', 'CA Mineiro', 'Atletico MG'],
#  ('BR', 'Atlético PR'): ['Atletico PR', 'Athletico-PR', 'Atletico Paranaense'],
#  ('BR', 'Avaí'): ['Avai'],
#  ('BR', 'Bahia'): ['Bahia', 'Bahia Salvador'],
#  ('BR', 'Botafogo'): ['Botafogo', 'Botafogo RJ'],
#  ('BR', 'CSA'): ['CSA', 'CSA AL', 'CSA AI'],
#  ('BR', 'Ceará'): ['Ceara', 'Ceara SC Fortaleza'],
#  ('BR', 'Chapecoense'): ['Chapecoense'],
#  ('BR', 'Corinthians'): ['Corinthians', 'Corinthians SP'],
#  ('BR', 'Coritiba'): ['Coritiba'],
#  ('BR', 'Cruzeiro'): ['Cruzeiro', 'Cruzeiro MG', 'EC Cruzeiro'],
#  ('BR', 'Figueirense'): ['Figueirense', 'Figueirense EC'],
#  ('BR', 'Flamengo'): ['Flamengo', 'Flamengo RJ'],
#  ('BR', 'Fluminense'): ['Fluminense', 'Fluminense FC'],
#  ('BR', 'Fortaleza'): ['Fortaleza', 'Fortaleza EC'],
#  ('BR', 'Goiás'): ['Goias', 'Goias GO'],
#  ('BR', 'Grêmio'): ['Gremio'],
#  ('BR', 'Internacional'): ['Internacional', 'Internacional SC'],
#  ('BR', 'Joinville'): ['Joinville'],
#  ('BR', 'Palmeiras'): ['Palmeiras', 'SE Palmeiras'],
#  ('BR', 'Paraná'): ['Parana', 'Parana Clube FC'],
#  ('BR', 'Ponte Preta'): ['Ponte Preta', 'AA Ponte Preta Campinas'],
#  ('BR', 'Santa Cruz'): ['Santa Cruz', 'Santa Cruz PE'],
#  ('BR', 'Santos'): ['Santos', 'Santos FC'],
#  ('BR', 'Sport Recife'): ['Sport Recife'],
#  ('BR', 'São Paulo'): ['Sao Paulo', 'Sao Paulo SP'],
#  ('BR', 'Vasco da Gama'): ['Vasco da Gama', 'Vasco Da Gama'],
#  ('BR', 'Vitória'): ['Vitoria', 'Vitoria BA'],
#  ('CN', 'Beijing Guoan'): ['Beijing Guoan'],
#  ('CN', 'Beijing Renhe'): ['Beijing Renhe', 'Guizhou Renhe'],
#  ('CN', 'Changchun Yatai'): ['Changchun Yatai'],
#  ('CN', 'Chongqing Dangdai Lifan'): ['Chongqing Lifan'],
#  ('CN', 'Dalian Yifang'): ['Dalian Yifang', 'Dalian Pro'],
#  ('CN', 'Guangzhou Evergrande'): ['Guangzhou FC'],
#  ('CN', 'Guangzhou R&F'): ['Guangzhou R&F'],
#  ('CN', 'Guizhou Zhicheng'): ['Guizhou HF Zhicheng', 'Guizhou HF Zhiche'],
#  ('CN', 'Hangzhou'): ['Hangzhou Greentown'],
#  ('CN', 'Hebei CFFC'): ['Hebei CFFC', 'Hebei'],
#  ('CN', 'Henan Jianye'): ['Henan'],
#  ('CN', 'Jiangsu Suning'): ['Jiangsu Suning'],
#  ('CN', 'Liaoning Kaixin'): ['Liaoning Whowin'],
#  ('CN', 'Shandong Luneng'): ['Shandong Luneng'],
#  ('CN', 'Shanghai SIPG'): ['Shanghai East Asia'],
#  ('CN', 'Shanghai Shenhua'): ['Shanghai Shenhua', 'Shanghai Shenhua FC'],
#  ('CN', 'Shanghai Shenxin'): ['Shanghai Shenxin'],
#  ('CN', 'Shenzhen'): ['Shenzhen', 'Shenzhen FC'],
#  ('CN', 'Shijiazhuang Ever Bright'): ['Shijiazhuan Ever Bright',
#   'Shijiazhuang Yongchang'],
#  ('CN', 'Tianjin Quanjian'): ['Tianjin Quanjian'],
#  ('CN', 'Tianjin Teda'): ['Tianjin Teda', 'Tianjin Jinmen Tiger FC'],
#  ('CN', 'Wuhan Zall'): ['Wuhan Zall', 'Wuhan Zall FC'],
#  ('CN', 'Yanbian Funde'): ['Yanbian Funde', 'Yanbian Fude'],
#  ('DE', '1860 München'): ['1860 Munchen', 'TSV 1860 Munchen', '1860 Munich'],
#  ('DE', 'Arminia Bielefeld'): ['Arminia Bielefeld'],
#  ('DE', 'Augsburg'): ['Augsburg'],
#  ('DE', 'Bayer Leverkusen'): ['Bayer Leverkusen', 'Leverkusen'],
#  ('DE', 'Bayern München'): ['Bayern Munich', 'B Munich'],
#  ('DE', 'Bochum'): ['Bochum'],
#  ('DE', 'Borussia Dortmund'): ['Borussia Dortmund', 'Dortmund'],
#  ('DE', "Borussia M'gladbach"): ['Mgladbach'],
#  ('DE', 'Darmstadt 98'): ['SV Darmstadt'],
#  ('DE', 'Dynamo Dresden'): ['Dynamo Dresden'],
#  ('DE', 'Eintracht Braunschweig'): ['Eintracht Braunschweig', 'Braunschweig'],
#  ('DE', 'Eintracht Frankfurt'): ['Eintracht Frankfurt'],
#  ('DE', 'Erzgebirge Aue'): ['Erzgebirge'],
#  ('DE', 'FSV Frankfurt'): ['FSV Frankfurt'],
#  ('DE', 'Fortuna Düsseldorf'): ['Fortuna Dusseldorf'],
#  ('DE', 'Freiburg'): ['Freiburg'],
#  ('DE', 'Greuther Fürth'): ['Greuther Furth', 'G Furth'],
#  ('DE', 'Hamburger SV'): ['Hamburger SV', 'Hamburg'],
#  ('DE', 'Hannover 96'): ['Hannover'],
#  ('DE', 'Heidenheim'): ['FC Heidenheim'],
#  ('DE', 'Hertha BSC'): ['Hertha Berlin'],
#  ('DE', 'Hoffenheim'): ['Hoffenheim'],
#  ('DE', 'Holstein Kiel'): ['Holstein Kiel'],
#  ('DE', 'Ingolstadt'): ['Ingolstadt'],
#  ('DE', 'Jahn Regensburg'): ['Jahn Regensburg'],
#  ('DE', 'Kaiserslautern'): ['Kaiserslautern'],
#  ('DE', 'Karlsruher SC'): ['Karlsruhe'],
#  ('DE', 'Köln'): ['FC Koln'],
#  ('DE', 'MSV Duisburg'): ['MSV Duisburg', 'Duisburg'],
#  ('DE', 'Magdeburg'): ['FC Magdeburg'],
#  ('DE', 'Mainz 05'): ['FSV Mainz 05', 'Mainz'],
#  ('DE', 'Nürnberg'): ['Nurnberg'],
#  ('DE', 'Osnabrück'): ['Osnabruck', 'VFL Osnabruck'],
#  ('DE', 'Paderborn'): ['Paderborn'],
#  ('DE', 'RB Leipzig'): ['RB Leipzig'],
#  ('DE', 'Sandhausen'): ['SV Sandhausen'],
#  ('DE', 'Schalke 04'): ['Schalke 04', 'Schalke'],
#  ('DE', 'St. Pauli'): ['St Pauli'],
#  ('DE', 'Stuttgart'): ['Stuttgart'],
#  ('DE', 'Union Berlin'): ['Union Berlin'],
#  ('DE', 'Wehen Wiesbaden'): ['Wehen Wiesbaden'],
#  ('DE', 'Werder Bremen'): ['Werder Bremen', 'W Bremen'],
#  ('DE', 'Wolfsburg'): ['Wolfsburg'],
#  ('DE', 'Würzburger Kickers'): ['Wurzburger Kickers', 'FC Wurzburger Kickers'],
#  ('ES', 'AD Alcorcón'): ['Alcorcon'],
#  ('ES', 'Albacete Balompié'): ['Albacete Balompie', 'Albacete'],
#  ('ES', 'Almería'): ['Almeria'],
#  ('ES', 'Athletic Club Bilbao'): ['Athletic Bilbao', 'Ath Bilbao'],
#  ('ES', 'Athletic Club II'): ['Athletic Bilbao B', 'Ath Bilbao B'],
#  ('ES', 'Atlético Madrid'): ['Atletico Madrid', 'Atl Madrid'],
#  ('ES', 'Barcelona II'): ['Barcelona B'],
#  ('ES', 'CA Osasuna'): ['Osasuna'],
#  ('ES', 'CD Lugo'): ['Lugo'],
#  ('ES', 'CD Numancia'): ['Numancia'],
#  ('ES', 'CD Tenerife'): ['Tenerife'],
#  ('ES', 'CF Fuenlabrada'): ['Fuenlabrada'],
#  ('ES', 'CF Reus Deportiu'): ['Reus Deportiu'],
#  ('ES', 'Celta de Vigo'): ['Celta Vigo'],
#  ('ES', 'Cultural y Deportiva Leonesa'): ['Cultural Leonesa', 'Leonesa'],
#  ('ES', 'Cádiz'): ['Cadiz'],
#  ('ES', 'Córdoba'): ['Cordoba'],
#  ('ES', 'Deportivo Alavés'): ['Alaves'],
#  ('ES', 'Deportivo La Coruña'): ['Deportivo La Coruna II', 'Deportivo'],
#  ('ES', 'Elche CF'): ['Elche'],
#  ('ES', 'Extremadura UD'): ['Extremadura UD', 'Extremadura'],
#  ('ES', 'FC Barcelona'): ['Barcelona'],
#  ('ES', 'Getafe CF'): ['Getafe'],
#  ('ES', 'Gimnàstic de Tarragona'): ['Gimnastic Tarragona', 'Gimnastic'],
#  ('ES', 'Girona FC'): ['Girona'],
#  ('ES', 'Granada CF'): ['Granada CF', 'Granada'],
#  ('ES', 'Leganés'): ['Leganes'],
#  ('ES', 'Levante UD'): ['Levante'],
#  ('ES', 'Llagostera-Costa Brava'): ['Llagostera', 'UE Llagostera'],
#  ('ES', 'Lorca'): ['Lorca FC', 'La Hoya Lorca'],
#  ('ES', 'Mirandés'): ['Mirandes', 'CD Mirandes'],
#  ('ES', 'Málaga CF'): ['Malaga'],
#  ('ES', 'RCD Espanyol'): ['Espanyol'],
#  ('ES', 'RCD Mallorca'): ['Mallorca'],
#  ('ES', 'Racing Santander'): ['Racing Santander'],
#  ('ES', 'Rayo Majadahonda'): ['Rayo Majadahonda', 'CF Rayo Majadahonda'],
#  ('ES', 'Rayo Vallecano'): ['Rayo Vallecano'],
#  ('ES', 'Real Betis'): ['Real Betis', 'Betis'],
#  ('ES', 'Real Madrid'): ['Real Madrid'],
#  ('ES', 'Real Oviedo'): ['Oviedo'],
#  ('ES', 'Real Sociedad'): ['Real Sociedad', 'Sociedad'],
#  ('ES', 'Real Valladolid'): ['Valladolid'],
#  ('ES', 'Real Zaragoza'): ['Zaragoza'],
#  ('ES', 'SD Eibar'): ['Eibar'],
#  ('ES', 'SD Huesca'): ['Huesca'],
#  ('ES', 'SD Ponferradina'): ['Ponferradina'],
#  ('ES', 'Sevilla FC'): ['Sevilla'],
#  ('ES', 'Sevilla II'): ['Sevilla B'],
#  ('ES', 'Sporting Gijón'): ['Sporting Gijon'],
#  ('ES', 'UCAM Murcia CF'): ['UCAM Murcia', 'Murcia'],
#  ('ES', 'UD Las Palmas'): ['UD Las Palmas', 'Las Palmas'],
#  ('ES', 'Valencia CF'): ['Valencia'],
#  ('ES', 'Villarreal'): ['Villarreal'],
#  ('FR', 'Ajaccio'): ['AC Ajaccio'],
#  ('FR', 'Amiens SC'): ['Amiens', 'SC Amiens'],
#  ('FR', 'Angers SCO'): ['Angers'],
#  ('FR', 'Auxerre'): ['Auxerre'],
#  ('FR', 'Bastia'): ['Bastia', 'SC Bastia'],
#  ('FR', 'Bordeaux'): ['Bordeaux', 'Bordeaux Stade'],
#  ('FR', 'Bourg-en-Bresse'): ['Bourg-en-Bresse',
#   'Bourg-en-Bresse Peronnas',
#   'Bourg-Peronnas'],
#  ('FR', 'Brest'): ['Brest', 'ASPTT Brest'],
#  ('FR', 'Béziers'): ['Beziers', 'AS Beziers'],
#  ('FR', 'Caen'): ['Caen'],
#  ('FR', 'Chambly'): ['Chambly FC',
#   'Chambly-Oise',
#   'Chambly Oise',
#   'Chambly Thelle'],
#  ('FR', 'Châteauroux'): ['Chateauroux'],
#  ('FR', 'Clermont'): ['Clermont'],
#  ('FR', 'Créteil'): ['Creteil'],
#  ('FR', 'Dijon'): ['Dijon'],
#  ('FR', 'Gazélec Ajaccio'): ['Gfc Ajaccio', 'Ajaccio GFCO'],
#  ('FR', 'Grenoble Foot 38'): ['Grenoble Foot 38', 'Grenoble'],
#  ('FR', 'Guingamp'): ['Guingamp'],
#  ('FR', 'Laval'): ['Laval'],
#  ('FR', 'Le Havre'): ['Le Havre'],
#  ('FR', 'Le Mans'): ['Le Mans'],
#  ('FR', 'Lens'): ['Lens'],
#  ('FR', 'Lille'): ['Lille'],
#  ('FR', 'Lorient'): ['Lorient'],
#  ('FR', 'Metz'): ['Metz'],
#  ('FR', 'Monaco'): ['Monaco'],
#  ('FR', 'Montpellier'): ['Montpellier', 'Montpellier Herault SC'],
#  ('FR', 'Nancy'): ['Nancy'],
#  ('FR', 'Nantes'): ['Nantes'],
#  ('FR', 'Nice'): ['Nice'],
#  ('FR', 'Niort'): ['Niort'],
#  ('FR', 'Nîmes'): ['Nimes'],
#  ('FR', 'Olympique Lyonnais'): ['Lyon'],
#  ('FR', 'Olympique Marseille'): ['Marseille'],
#  ('FR', 'Orléans'): ['Orleans'],
#  ('FR', 'PSG'): ['PSG', 'Paris St-G'],
#  ('FR', 'Paris'): ['Paris FC'],
#  ('FR', 'Quevilly Rouen'): ['Quevilly Rouen', 'Quevilly', 'US Quevilly'],
#  ('FR', 'Red Star'): ['Red Star', 'Red Star FC'],
#  ('FR', 'Reims'): ['Reims'],
#  ('FR', 'Rennes'): ['Rennes'],
#  ('FR', 'Rodez '): ['Rodez', 'Rodez AF', 'Rodez Aveyron'],
#  ('FR', 'Saint-Étienne'): ['Saint-Etienne', 'St Etienne'],
#  ('FR', 'Sochaux'): ['Sochaux'],
#  ('FR', 'Strasbourg'): ['Strasbourg'],
#  ('FR', 'Thonon Evian FC'): ['Evian TG'],
#  ('FR', 'Toulouse'): ['Toulouse', 'Toulouse FC'],
#  ('FR', 'Tours'): ['Tours'],
#  ('FR', 'Troyes'): ['Troyes', 'ESTAC Troyes'],
#  ('FR', 'Valenciennes'): ['Valenciennes'],
#  ('GB', 'AFC Bournemouth'): ['AFC Bournemouth', 'Bournemouth'],
#  ('GB', 'Aberdeen'): ['Aberdeen'],
#  ('GB', 'Arsenal'): ['Arsenal'],
#  ('GB', 'Aston Villa'): ['Aston Villa'],
#  ('GB', 'Barnsley'): ['Barnsley'],
#  ('GB', 'Birmingham City'): ['Birmingham'],
#  ('GB', 'Blackburn Rovers'): ['Blackburn'],
#  ('GB', 'Bolton Wanderers'): ['Bolton'],
#  ('GB', 'Brentford'): ['Brentford'],
#  ('GB', 'Brighton & Hove Albion'): ['Brighton'],
#  ('GB', 'Bristol City'): ['Bristol City'],
#  ('GB', 'Burnley'): ['Burnley'],
#  ('GB', 'Burton Albion'): ['Burton Albion', 'Burton'],
#  ('GB', 'Cardiff City'): ['Cardiff City', 'Cardiff'],
#  ('GB', 'Celtic'): ['Celtic'],
#  ('GB', 'Charlton Athletic'): ['Charlton Athletic', 'Charlton'],
#  ('GB', 'Chelsea'): ['Chelsea'],
#  ('GB', 'Crystal Palace'): ['Crystal Palace', 'C Palace'],
#  ('GB', 'Derby County'): ['Derby'],
#  ('GB', 'Dundee'): ['Dundee'],
#  ('GB', 'Dundee United'): ['Dundee Utd'],
#  ('GB', 'Everton'): ['Everton'],
#  ('GB', 'Fulham'): ['Fulham'],
#  ('GB', 'Hamilton Academical'): ['Hamilton'],
#  ('GB', 'Hearts'): ['Hearts'],
#  ('GB', 'Hibernian'): ['Hibernian'],
#  ('GB', 'Huddersfield Town'): ['Huddersfield Town', 'Huddersfield'],
#  ('GB', 'Hull City'): ['Hull City', 'Hull'],
#  ('GB', 'Inverness CT'): ['Inverness CT'],
#  ('GB', 'Ipswich Town'): ['Ipswich Town', 'Ipswich'],
#  ('GB', 'Kilmarnock'): ['Kilmarnock'],
#  ('GB', 'Leeds United'): ['Leeds Utd', 'Leeds'],
#  ('GB', 'Leicester City'): ['Leicester City', 'Leicester'],
#  ('GB', 'Liverpool'): ['Liverpool'],
#  ('GB', 'Livingston'): ['Livingston'],
#  ('GB', 'Luton Town'): ['Luton Town', 'Luton'],
#  ('GB', 'Manchester City'): ['Manchester City', 'Man City'],
#  ('GB', 'Manchester United'): ['Man United', 'Man Utd'],
#  ('GB', 'Middlesbrough'): ['Middlesbrough'],
#  ('GB', 'Millwall'): ['Millwall', 'Millwal'],
#  ('GB', 'Milton Keynes Dons'): ['Milton Keynes Dons', 'M K Dons', 'MK Dons'],
#  ('GB', 'Motherwell'): ['Motherwell'],
#  ('GB', 'Newcastle United'): ['Newcastle'],
#  ('GB', 'Norwich City'): ['Norwich City', 'Norwich'],
#  ('GB', 'Nottingham Forest'): ['Nottingham Forest', 'Nottm Forest'],
#  ('GB', 'Partick Thistle'): ['Partick'],
#  ('GB', 'Preston North End'): ['Preston'],
#  ('GB', 'Queens Park Rangers'): ['Queens Park', 'QPR'],
#  ('GB', 'Rangers'): ['Rangers'],
#  ('GB', 'Reading'): ['Reading'],
#  ('GB', 'Ross County'): ['Ross Co'],
#  ('GB', 'Rotherham United'): ['Rotherham Utd', 'Rotherham'],
#  ('GB', 'Sheffield United'): ['Sheffield United', 'Sheff Utd', 'Sheffield'],
#  ('GB', 'Sheffield Wednesday'): ['Sheffield Wednesday', 'Sheff Wed'],
#  ('GB', 'Southampton'): ['Southampton'],
#  ('GB', 'St. Johnstone'): ['St Johnstone', 'St Johnstone '],
#  ('GB', 'St. Mirren'): ['St Mirren'],
#  ('GB', 'Stoke City'): ['Stoke City', 'Stoke'],
#  ('GB', 'Sunderland'): ['Sunderland'],
#  ('GB', 'Swansea City'): ['Swansea'],
#  ('GB', 'Tottenham Hotspur'): ['Tottenham'],
#  ('GB', 'Watford'): ['Watford'],
#  ('GB', 'West Bromwich Albion'): ['West Brom'],
#  ('GB', 'West Ham United'): ['West Ham'],
#  ('GB', 'Wigan Athletic'): ['Wigan Athletic', 'Wigan'],
#  ('GB', 'Wolverhampton Wanderers'): ['Wolves'],
#  ('IL', 'Ashdod'): ['MS Ashdod', 'FC Ashdod'],
#  ('IL', 'Beitar Jerusalem'): ['Beitar Jerusalem'],
#  ('IL', 'Bnei Sakhnin'): ['Bnei Sakhnin'],
#  ('IL', 'Bnei Yehuda'): ['Bnei Yehuda'],
#  ('IL', 'Hapoel Acre'): ['Hapoel Akko'],
#  ('IL', 'Hapoel Ashkelon'): ['Hapoel Ashkelon', 'FC Hapoel Ashkelon'],
#  ('IL', "Hapoel Be'er Sheva"): ['Hapoel Beer Sheva'],
#  ('IL', 'Hapoel Hadera'): ['Hapoel Hadera', 'Hapoel Eran Hadera'],
#  ('IL', 'Hapoel Haifa'): ['Hapoel Haifa'],
#  ('IL', 'Hapoel Kfar Saba'): ['Hapoel Kfar Saba', 'Hapoel K Saba'],
#  ('IL', "Hapoel Ra'anana"): ['Hapoel Raanana'],
#  ('IL', 'Hapoel Tel Aviv'): ['Hapoel Tel Aviv'],
#  ('IL', 'Ironi Kiryat Shmona'): ['Hapoel Kiryat Shmona',
#   'Hapoel Ironi Kiryat Sh'],
#  ('IL', 'Maccabi Haifa'): ['Maccabi Haifa'],
#  ('IL', 'Maccabi Netanya'): ['Maccabi Netanya'],
#  ('IL', 'Maccabi Petah Tikva'): ['Maccabi Petah Tikva',
#   'Maccabi Petach Tikva',
#   'Maccabi Ironi Petah Tikva'],
#  ('IL', 'Maccabi Tel Aviv'): ['Maccabi Tel Aviv'],
#  ('IL', 'Sektzia Nes Tziona'): ['Sektzia Nes Tziona'],
#  ('IT', 'AC Milan'): ['AC Milan'],
#  ('IT', 'Ascoli'): ['Ascoli'],
#  ('IT', 'Atalanta'): ['Atalanta'],
#  ('IT', 'Avellino'): ['Avellino', 'Calcio Avellino', 'Calcio Avellino SSD'],
#  ('IT', 'Bari 1908'): ['Bari', 'SSD Bari'],
#  ('IT', 'Benevento'): ['Benevento'],
#  ('IT', 'Bologna'): ['Bologna'],
#  ('IT', 'Brescia'): ['Brescia'],
#  ('IT', 'Cagliari'): ['Cagliari'],
#  ('IT', 'Calcio Padova'): ['Padova'],
#  ('IT', 'Carpi'): ['Carpi'],
#  ('IT', 'Cesena'): ['Cesena', 'RC Cesena FC'],
#  ('IT', 'Chievo'): ['Chievo'],
#  ('IT', 'Cittadella'): ['Cittadella'],
#  ('IT', 'Como'): ['Como'],
#  ('IT', 'Cosenza'): ['Cosenza'],
#  ('IT', 'Cremonese'): ['Cremonese', 'US Cremonese'],
#  ('IT', 'Crotone'): ['Crotone'],
#  ('IT', 'Empoli'): ['Empoli'],
#  ('IT', 'Fiorentina'): ['Fiorentina'],
#  ('IT', 'Foggia'): ['Foggia'],
#  ('IT', 'Frosinone'): ['Frosinone'],
#  ('IT', 'Genoa'): ['Genoa'],
#  ('IT', 'Hellas Verona'): ['Hellas Verona', 'Verona'],
#  ('IT', 'Inter Milan'): ['Inter Milan', 'Inter'],
#  ('IT', 'Juve Stabia'): ['Juve Stabia'],
#  ('IT', 'Juventus'): ['Juventus'],
#  ('IT', 'Latina'): ['Latina'],
#  ('IT', 'Lazio'): ['Lazio'],
#  ('IT', 'Lecce'): ['Lecce'],
#  ('IT', 'Livorno'): ['Livorno'],
#  ('IT', 'Modena'): ['Modena', 'Modena FC 2018 SSD'],
#  ('IT', 'Napoli'): ['Napoli'],
#  ('IT', 'Novara'): ['Novara'],
#  ('IT', 'Palermo'): ['Palermo'],
#  ('IT', 'Parma'): ['Parma'],
#  ('IT', 'Perugia'): ['Perugia'],
#  ('IT', 'Pescara'): ['Pescara'],
#  ('IT', 'Pisa'): ['Pisa'],
#  ('IT', 'Pordenone'): ['Pordenone', 'Pordenone Calcio'],
#  ('IT', 'Pro Vercelli'): ['Pro Vercelli', 'Pro Vercelli 1892'],
#  ('IT', 'Roma'): ['Roma'],
#  ('IT', 'SPAL'): ['Spal'],
#  ('IT', 'Salernitana'): ['Salernitana'],
#  ('IT', 'Sampdoria'): ['Sampdoria'],
#  ('IT', 'Sassuolo'): ['Sassuolo'],
#  ('IT', 'Spezia'): ['Spezia'],
#  ('IT', 'Ternana'): ['Ternana'],
#  ('IT', 'Torino'): ['Torino'],
#  ('IT', 'Trapani'): ['Trapani'],
#  ('IT', 'Udinese'): ['Udinese'],
#  ('IT', 'Venezia'): ['Venezia'],
#  ('IT', 'Vicenza'): ['Vicenza', 'LR Vicenza Virtus'],
#  ('IT', 'Virtus Entella'): ['Entella'],
#  ('IT', 'Virtus Lanciano'): ['Lanciano'],
#  ('JP', 'Albirex Niigata'): ['Albirex Niigata', 'Niigata'],
#  ('JP', 'Avispa Fukuoka'): ['Fukuoka'],
#  ('JP', 'Cerezo Osaka'): ['Cerezo Osaka', 'C-Osaka'],
#  ('JP', 'Consadole Sapporo'): ['Consadole Sapporo', 'Sapporo'],
#  ('JP', 'Gamba Osaka'): ['Gamba Osaka', 'G-Osaka'],
#  ('JP', 'Jubilo Iwata'): ['Jubilo Iwata', 'Iwata'],
#  ('JP', 'Kashima Antlers'): ['Kashima Antlers', 'Kashima'],
#  ('JP', 'Kashiwa Reysol'): ['Kashiwa Reysol', 'Kashiwa'],
#  ('JP', 'Kawasaki Frontale'): ['Kawasaki Frontale', 'Kawasaki'],
#  ('JP', 'Matsumoto Yamaga'): ['Matsumoto Yamaga FC', 'Matsumoto'],
#  ('JP', 'Montedio Yamagata'): ['Yamagata'],
#  ('JP', 'Nagoya Grampus'): ['Nagoya Grampus', 'Nagoya'],
#  ('JP', 'Oita Trinita'): ['Oita'],
#  ('JP', 'Omiya Ardija'): ['Omiya Ardija', 'Omiya'],
#  ('JP', 'Sagan Tosu'): ['Sagan Tosu', 'Tosu'],
#  ('JP', 'Sanfrecce Hiroshima'): ['Hiroshima'],
#  ('JP', 'Shimizu S-Pulse'): ['Shimizu S Pulse', 'Shimizu'],
#  ('JP', 'Shonan Bellmare'): ['Shonan Bellmare', 'Shonan'],
#  ('JP', 'Tokyo'): ['FC Tokyo'],
#  ('JP', 'Urawa Reds'): ['Urawa'],
#  ('JP', 'V-Varen Nagasaki'): ['V-Varen Nagasaki', 'Nagasaki'],
#  ('JP', 'Vegalta Sendai'): ['Vegalta Sendai', 'Sendai'],
#  ('JP', 'Ventforet Kofu'): ['Kofu'],
#  ('JP', 'Vissel Kobe'): ['Vissel Kobe', 'Kobe'],
#  ('JP', 'Yokohama'): ['Yokohama FC'],
#  ('JP', 'Yokohama F. Marinos'): ['Yokohama F Marinos', 'Yokohama FM'],
#  ('NL', 'ADO Den Haag'): ['ADO Den Haag'],
#  ('NL', 'AZ'): ['Az Alkmaar'],
#  ('NL', 'Ajax'): ['Ajax'],
#  ('NL', 'Cambuur'): ['Cambuur', 'SC Cambuur', 'Cambuur Leeuwarden'],
#  ('NL', 'De Graafschap'): ['De Graafschap'],
#  ('NL', 'Emmen'): ['Emmen'],
#  ('NL', 'Excelsior'): ['Excelsior'],
#  ('NL', 'Feyenoord'): ['Feyenoord', 'SC Feyenoord'],
#  ('NL', 'Fortuna Sittard'): ['Fortuna Sittard', 'Sittard'],
#  ('NL', 'Go Ahead Eagles'): ['Go Ahead Eagles'],
#  ('NL', 'Groningen'): ['Groningen', 'FC Groningen', 'FC GRONINGEN'],
#  ('NL', 'Heerenveen'): ['Heerenveen'],
#  ('NL', 'Heracles'): ['Heracles'],
#  ('NL', 'NAC Breda'): ['NAC Breda', 'Breda'],
#  ('NL', 'NEC'): ['NEC Nijmegen'],
#  ('NL', 'PEC Zwolle'): ['PEC Zwolle', 'Zwolle'],
#  ('NL', 'PSV'): ['PSV'],
#  ('NL', 'RKC Waalwijk'): ['RKC Waalwijk', 'Waalwijk'],
#  ('NL', 'Roda JC'): ['Roda JC', 'Roda JC Kerkrade'],
#  ('NL', 'Sparta Rotterdam'): ['Sparta Rotterdam'],
#  ('NL', 'Twente'): ['Twente', 'FC Twente'],
#  ('NL', 'Utrecht'): ['Utrecht', 'FC Utrecht'],
#  ('NL', 'VVV'): ['VVV', 'VVV Venlo'],
#  ('NL', 'Vitesse'): ['Vitesse', 'Vitesse Arnhem'],
#  ('NL', 'Willem II'): ['Willem II'],
#  ('PT', 'Associação Académica de Coimbra OAF'): ['Academica Coimbra',
#   'Academica Coimbra-SF',
#   'Academica'],
#  ('PT', 'Benfica'): ['Benfica'],
#  ('PT', 'Boavista FC'): ['Boavista'],
#  ('PT', 'CD Aves'): ['Aves'],
#  ('PT', 'CD Feirense'): ['Feirense'],
#  ('PT', 'CD Nacional'): ['Nacional',
#   'CD Nacional Funchal',
#   'Nacional Madeira'],
#  ('PT', 'CD Tondela'): ['Tondela'],
#  ('PT', 'CF Os Belenenses'): ['Cf Os Belenenses', 'Belenenses'],
#  ('PT', 'CF União'): ['Uniao', 'Uniao Madeira'],
#  ('PT', 'CS Marítimo'): ['Maritimo'],
#  ('PT', 'FC Arouca'): ['Arouca'],
#  ('PT', 'Famalicão'): ['Famalicao'],
#  ('PT', 'GD Chaves'): ['Chaves'],
#  ('PT', 'GD Estoril Praia'): ['Estoril Praia', 'Estoril'],
#  ('PT', 'Gil Vicente'): ['Gil Vicente'],
#  ('PT', 'Moreirense FC'): ['Moreirense'],
#  ('PT', 'Paços de Ferreira'): ['Pacos Ferreira'],
#  ('PT', 'Portimonense'): ['Portimonense'],
#  ('PT', 'Porto'): ['Porto'],
#  ('PT', 'Rio Ave FC'): ['Rio Ave'],
#  ('PT', 'Santa Clara'): ['Santa Clara'],
#  ('PT', 'Sporting Braga'): ['Braga'],
#  ('PT', 'Sporting CP'): ['Sporting Lisbon'],
#  ('PT', 'Vitória Guimarães'): ['Guimaraes', 'Guimarares'],
#  ('PT', 'Vitória Setúbal'): ['Vitoria Setubal', 'Setubal'],
#  ('RU', 'Akhmat Grozny'): ['Akhmat Grozny', 'Terek Grozni'],
#  ('RU', 'Amkar Perm'): ['Amkar Perm', 'Amkar'],
#  ('RU', 'Anzhi Makhachkala'): ['Anzhi Makhachkala'],
#  ('RU', 'Arsenal Tula'): ['Arsenal Tula'],
#  ('RU', 'CSKA Moskva'): ['CSKA Moscow'],
#  ('RU', 'Dinamo Moskva'): ['Dinamo Moscow'],
#  ('RU', 'FK Sochi'): ['FK Sochi', 'FC Sochi', 'Sochi'],
#  ('RU', 'Krasnodar'): ['FK Krasnodar'],
#  ('RU', 'Krylya Sovetov'): ['Kryliya Sovetov', 'Krilya Sovetov CPF'],
#  ('RU', 'Kuban Krasnodar'): ['Kuban Krasnodar'],
#  ('RU', 'Lokomotiv Moskva'): ['Lokomotiv'],
#  ('RU', 'Mordovia Saransk'): ['Mordovia Saransk', 'Mordovya Saransk'],
#  ('RU', 'Orenburg'): ['FC Orenburg', 'Gazovik Orenburg'],
#  ('RU', 'Rostov'): ['Rostov'],
#  ('RU', 'Rubin Kazan'): ['Rubin Kazan'],
#  ('RU', 'SKA Khabarovsk'): ['SKA-Khabarovsk', 'Ska Energia Khabarovsk'],
#  ('RU', 'Spartak Moskva'): ['Spartak Moscow'],
#  ('RU', 'Tambov'): ['FK Tambov', 'FC Tambov'],
#  ('RU', "Tom' Tomsk"): ['Tom Tomsk', 'Tomsk'],
#  ('RU', 'Tosno'): ['Tosno'],
#  ('RU', 'Ufa'): ['FC Ufa'],
#  ('RU', 'Ural'): ['Ural'],
#  ('RU', 'Yenisey'): ['FK Yenisey', 'Yenisey Krasnoyarsk'],
#  ('RU', 'Zenit'): ['Zenit St Petersburg'],
#  ('TR', 'Adanaspor'): ['Adanaspor'],
#  ('TR', 'Akhisar Belediyespor'): ['Akhisar Belediye', 'Akhisar Bld Spor'],
#  ('TR', 'Alanyaspor'): ['Alanyaspor'],
#  ('TR', 'Ankaragücü'): ['Ankaragucu'],
#  ('TR', 'Antalyaspor'): ['Antalyaspor'],
#  ('TR', 'BB Erzurumspor'): ['Erzurum BB'],
#  ('TR', 'Beşiktaş'): ['Besiktas'],
#  ('TR', 'Bursaspor'): ['Bursaspor'],
#  ('TR', 'Denizlispor'): ['Denizlispor'],
#  ('TR', 'Eskişehirspor'): ['Eskisehirspor'],
#  ('TR', 'Fenerbahçe'): ['Fenerbahce'],
#  ('TR', 'Galatasaray'): ['Galatasaray'],
#  ('TR', 'Gaziantepspor'): ['Gaziantepspor'],
#  ('TR', 'Gazişehir Gaziantep'): ['Gazisehir Gaziantep FK',
#   'Gaziantep',
#   'Gaziantep FK',
#   'Gaziantep BB'],
#  ('TR', 'Gençlerbirliği'): ['Genclerbirligi'],
#  ('TR', 'Göztepe'): ['Goztepe'],
#  ('TR', 'Karabükspor'): ['Karabukspor'],
#  ('TR', 'Kasımpaşa'): ['Kasimpasa'],
#  ('TR', 'Kayserispor'): ['Kayserispor'],
#  ('TR', 'Konyaspor'): ['Konyaspor', 'Torku Konyaspor', 'Atiker Konyaspor'],
#  ('TR', 'Mersin İdmanyurdu'): ['Mersin Idman Yurdu'],
#  ('TR', 'Osmanlıspor'): ['Osmanlispor'],
#  ('TR', 'Rizespor'): ['Rizespor'],
#  ('TR', 'Sivasspor'): ['Sivasspor'],
#  ('TR', 'Trabzonspor'): ['Trabzonspor'],
#  ('TR', 'Yeni Malatyaspor'): ['Yeni Malatyaspor', 'Malatyaspor'],
#  ('TR', 'İstanbul Başakşehir'): ['Istanbul Basaksehir',
#   'Istanbul BB',
#   'Basaksehir'],
#  ('US', 'Atlanta United FC'): ['Atlanta United',
#   'Atlanta Utd FC',
#   'Atlanta Utd'],
#  ('US', 'Chicago Fire'): ['Chicago Fire'],
#  ('US', 'Colorado Rapids'): ['Colorado Rapids', 'Colorado'],
#  ('US', 'Columbus Crew'): ['Columbus Crew', 'Columbus'],
#  ('US', 'DC United'): ['DC United', 'DC Utd'],
#  ('US', 'FC Cincinnati'): ['FC Cincinnati'],
#  ('US', 'FC Dallas'): ['FC Dallas', 'Dallas'],
#  ('US', 'Houston Dynamo'): ['Houston Dynamo'],
#  ('US', 'Inter Miami'): ['Inter Miami CF', 'Inter'],
#  ('US', 'LA Galaxy'): ['LA Galaxy'],
#  ('US', 'Los Angeles FC'): ['Los Angeles FC'],
#  ('US', 'Minnesota United'): ['Minnesota Utd'],
#  ('US', 'Montreal Impact'): ['Montreal Impact', 'CF Montreal'],
#  ('US', 'Nashville SC'): ['Nashville SC', 'Nashville FC'],
#  ('US', 'New England Revolution'): ['New England Revolution', 'New England'],
#  ('US', 'New York City'): ['New York City', 'New York City FC'],
#  ('US', 'New York RB'): ['New York Red Bulls'],
#  ('US', 'Orlando City'): ['Orlando City'],
#  ('US', 'Philadelphia Union'): ['Philadelphia Union', 'Philadelphia'],
#  ('US', 'Portland Timbers'): ['Portland Timbers'],
#  ('US', 'Real Salt Lake'): ['Real Salt Lake'],
#  ('US', 'SJ Earthquakes'): ['San Jose Earthquakes'],
#  ('US', 'Seattle Sounders'): ['Seattle Sounders', 'Seattle'],
#  ('US', 'Sporting KC'): ['Sporting Kansas', 'Kansas City'],
#  ('US', 'Toronto'): ['Toronto FC'],
#  ('US', 'Vancouver Whitecaps'): ['Vancouver Whitecaps']}

# %% [markdown]
# Export

# %%
TEAM_NAMES_MAPPING_PATH = '../data/interim/team_names_mapping.json'

# %%
# JSON keys must be str, int, float, bool or None, not tuple.
# so we use the string representation of the tuples.
team_names_mapping_tuples_as_strings = {str(k): v for k, v in team_names_mapping.items()}

with open(TEAM_NAMES_MAPPING_PATH, "w") as outfile:
    json.dump(team_names_mapping_tuples_as_strings, outfile)

# %% [markdown]
# ## search `event id`s

# %% [markdown]
# Now we can get Betfair `event id`s for the relevant matches in the footystats data set.
# So we:
#  - iterate over the `footy` DataFrame;
#  - filter the row(s) in the Betfair `event_basic_info_df` DataFrame that have:
#      - the same country as the instance in the `footy` DataFrame;
#      - compatible home and away team names;
#      - the same match start datetime.

# %% [markdown]
# Get a list of lists `event_ids`: each element is a list with the Betfair `event id`(s) found for each match.

# %%
event_ids = []

for i in tqdm(range(len(footy))):
    mask_country = event_basic_info_df['country_caus'] == footy.iloc[i]['country_code']
    # bf datetime is TZ aware and footy datetime is not. So explicitly set `.tz_localize(pytz.UTC)`
    mask_datetime = event_basic_info_df['open_date'] == footy.iloc[i]['date_GMT'].tz_localize(pytz.UTC)
    mask_home = event_basic_info_df['home_team'].isin(team_names_mapping[(footy.iloc[i]['country_code'], footy.iloc[i]['home_team_name'])])
    mask_away = event_basic_info_df['away_team'].isin(team_names_mapping[(footy.iloc[i]['country_code'], footy.iloc[i]['away_team_name'])])
    mask = mask_country * mask_datetime * mask_home * mask_away
    event_ids.append(list(event_basic_info_df[mask]['event_id'].values))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 36086/36086 [53:02<00:00, 11.34it/s]

# %%
# inspect a few examples
event_ids[:5]
# Out:
# [['27433105'], ['27433103'], ['27433106'], [], ['27433114']]

# %% [markdown]
# Let us check how many relevant matches have Betfair market data.

# %%
event_ids_lens = [len(elt) for elt in event_ids]

# %%
pd.Series(event_ids_lens).value_counts()
# Out:
# 1    32047
# 0     3956
# 2       82
# 3        1
# dtype: int64

# %%
(pd.Series(event_ids_lens).value_counts().sum() - pd.Series(event_ids_lens).value_counts()[0]) / pd.Series(event_ids_lens).value_counts().sum()
# Out:
# 0.8903729978384969

# %% [markdown]
# Betfair `event id`s were found for 89% of relevant matches.
# We contacted Betfair and they confirmed that historical data is not available for all matches that actually occured and for which there was a betting market.
# The reasons are technical and may be assumed random.
#
# Let us investigate the small number of matches with more than one `event id`.

# %%
mask_more_than_one_event_id = [True if len(elt) > 1 else False for elt in event_ids]

# %%
pd.Series(mask_more_than_one_event_id).value_counts()
# Out:
# False    36003
# True        83
# dtype: int64

# %% [markdown]
# We inspect the data on those matches.
# The DataFrame `more_than_one_event_id` is a subset of Betfair `event_basic_info_df` for those matches.

# %%
more_than_one_event_id = pd.DataFrame()

for i in tqdm(range(len(footy[mask_more_than_one_event_id]))):
    mask_country = event_basic_info_df['country_caus'] == footy[mask_more_than_one_event_id].iloc[i]['country_code']
    # bf datetime is TZ aware and footy datetime is not. So explicitly set `.tz_localize(pytz.UTC)`
    mask_datetime = event_basic_info_df['open_date'] == footy[mask_more_than_one_event_id].iloc[i]['date_GMT'].tz_localize(pytz.UTC)
    mask_home = event_basic_info_df['home_team'].isin(team_names_mapping[(footy[mask_more_than_one_event_id].iloc[i]['country_code'], footy[mask_more_than_one_event_id].iloc[i]['home_team_name'])])
    mask_away = event_basic_info_df['away_team'].isin(team_names_mapping[(footy[mask_more_than_one_event_id].iloc[i]['country_code'], footy[mask_more_than_one_event_id].iloc[i]['away_team_name'])])
    mask = mask_country * mask_datetime * mask_home * mask_away
    # event_ids.append(list(event_basic_info_df[mask]['event_id'].values))
    more_than_one_event_id = pd.concat([more_than_one_event_id, event_basic_info_df[mask]])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 83/83 [00:08<00:00, 10.25it/s]

# %%
pd.options.display.max_rows = 200

# %% [markdown]
# Let us inspect the DataFrame with data on matches with more than one compatible event id.

# %%
more_than_one_event_id
# Out:
#         event_id country                 open_date                 home_team  \
# 298208  28970987      AR 2018-10-27 00:00:00+00:00                   Huracan
# 298363  28962339      AR 2018-10-27 00:00:00+00:00                   Huracan
# 298217  28972910      AR 2018-10-27 18:00:00+00:00               River Plate
# 298364  28962340      AR 2018-10-27 18:00:00+00:00               River Plate
# 298216  28972909      AR 2018-10-27 20:15:00+00:00         Gimnasia La Plata
# 298365  28962342      AR 2018-10-27 20:15:00+00:00         Gimnasia La Plata
# 277185  28704749      AU 2018-05-05 09:50:00+00:00                 Newcastle
# 277186  28704764      AU 2018-05-05 09:50:00+00:00            Newcastle Jets
# 295910  28704774      AU 2018-05-05 09:50:00+00:00            Newcastle Jets
# 297231  28831913      AU 2018-10-19 08:50:00+00:00           Adelaide United
# 297232  28831913      AU 2018-10-19 08:50:00+00:00           Adelaide United
# 297744  28831916      AU 2018-10-21 04:00:00+00:00        Wellington Phoenix
# 297745  28831916      AU 2018-10-21 04:00:00+00:00        Wellington Phoenix
# 19656   29053589      AU 2019-01-05 06:35:00+00:00           Adelaide United
# 22254   29065462      AU 2019-01-05 06:35:00+00:00           Adelaide United
# 16993   29121265      AU 2019-02-23 06:35:00+00:00        Wellington Phoenix
# 18103   29125193      AU 2019-02-23 06:35:00+00:00        Wellington Phoenix
# 17245   29121269      AU 2019-02-24 08:00:00+00:00  Western Sydney Wanderers
# 18394   29125199      AU 2019-02-24 08:00:00+00:00  Western Sydney Wanderers
# 35430   29527488      AU 2019-10-19 08:30:00+00:00    Central Coast Mariners
# 35432   29527488      AU 2019-10-19 08:30:00+00:00    Central Coast Mariners
# 31107   29552613      AU 2019-11-01 08:30:00+00:00                    Sydney
# 31108   29552613      AU 2019-11-01 08:30:00+00:00                    Sydney
# 31690   29577570      AU 2019-11-16 08:30:00+00:00            Western United
# 31691   29577570      AU 2019-11-16 08:30:00+00:00            Western United
# 226932  27915291      BR 2016-09-08 00:45:00+00:00                  Coritiba
# 227592  27909692      BR 2016-09-08 00:45:00+00:00                  Coritiba
# 226934  27915295      BR 2016-09-09 00:00:00+00:00             Internacional
# 227655  27909690      BR 2016-09-09 00:00:00+00:00             Internacional
# 147453  27506646      CN 2015-08-11 11:35:00+00:00        Hangzhou Greentown
# 150668  27504801      CN 2015-08-11 11:35:00+00:00        Hangzhou Greentown
# 147452  27506644      CN 2015-08-11 11:35:00+00:00           Chongqing Lifan
# 150669  27504803      CN 2015-08-11 11:35:00+00:00           Chongqing Lifan
# 10560   29406298      CN 2019-08-11 11:35:00+00:00             Beijing Guoan
# 10561   29406300      CN 2019-08-11 11:35:00+00:00             Beijing Guoan
# 233854  28287998      GB 2017-08-12 14:00:00+00:00                  C Palace
# 252420  28271225      GB 2017-08-12 14:00:00+00:00            Crystal Palace
# 234580  28288000      GB 2017-08-19 14:00:00+00:00                 Liverpool
# 252426  28271454      GB 2017-08-19 14:00:00+00:00                 Liverpool
# 235117  28288003      GB 2017-08-20 12:30:00+00:00              Huddersfield
# 237604  28337301      GB 2017-08-20 12:30:00+00:00              Huddersfield
# 235115  28271459      GB 2017-08-20 15:00:00+00:00                 Tottenham
# 237601  28337289      GB 2017-08-20 15:00:00+00:00                 Tottenham
# 235352  28271455      GB 2017-08-21 19:00:00+00:00                  Man City
# 237602  28337300      GB 2017-08-21 19:00:00+00:00                  Man City
# 262756  28474130      GB 2017-11-28 19:45:00+00:00            Leicester City
# 264528  28477107      GB 2017-11-28 19:45:00+00:00                 Leicester
# 262758  28474151      GB 2017-11-29 20:00:00+00:00                Stoke City
# 264612  28477111      GB 2017-11-29 20:00:00+00:00                     Stoke
# 239043  28477113      GB 2017-12-02 15:00:00+00:00                 Leicester
# 262760  28474255      GB 2017-12-02 15:00:00+00:00            Leicester City
# 239045  28477114      GB 2017-12-02 15:00:00+00:00                     Stoke
# 262762  28474256      GB 2017-12-02 15:00:00+00:00                Stoke City
# 230438  28201642      FR 2017-04-24 18:45:00+00:00                  Le Havre
# 231062  28202031      FR 2017-04-24 18:45:00+00:00                  Le Havre
# 16586   29112522      FR 2019-02-11 19:45:00+00:00                     Brest
# 19354   29114300      FR 2019-02-11 19:45:00+00:00                     Brest
# 13354   29403799      FR 2019-08-09 18:00:00+00:00                     Niort
# 13399   29403800      FR 2019-08-09 18:00:00+00:00                     Niort
# 13348   29403767      FR 2019-08-09 18:00:00+00:00                   Le Mans
# 13393   29403765      FR 2019-08-09 18:00:00+00:00                   Le Mans
# 13355   29403802      FR 2019-08-09 18:00:00+00:00              ESTAC Troyes
# 13400   29403801      FR 2019-08-09 18:00:00+00:00              ESTAC Troyes
# 13352   29403795      FR 2019-08-09 18:00:00+00:00                     Rodez
# 13397   29403796      FR 2019-08-09 18:00:00+00:00                     Rodez
# 13351   29403794      FR 2019-08-09 18:00:00+00:00                  Guingamp
# 13396   29403793      FR 2019-08-09 18:00:00+00:00                  Guingamp
# 13350   29403788      FR 2019-08-09 18:00:00+00:00                AC Ajaccio
# 13395   29403792      FR 2019-08-09 18:00:00+00:00                AC Ajaccio
# 13353   29403798      FR 2019-08-09 18:00:00+00:00                     Nancy
# 13398   29403797      FR 2019-08-09 18:00:00+00:00                     Nancy
# 13349   29403786      FR 2019-08-09 18:00:00+00:00                   Sochaux
# 13394   29403787      FR 2019-08-09 18:00:00+00:00                   Sochaux
# 240981  28099222      DE 2017-02-12 12:30:00+00:00                  St Pauli
# 241680  28110933      DE 2017-02-12 12:30:00+00:00                  St Pauli
# 249924  28314570      DE 2017-07-29 11:00:00+00:00                Ingolstadt
# 250460  28296962      DE 2017-07-29 11:00:00+00:00                Ingolstadt
# 250290  28314568      DE 2017-07-29 13:30:00+00:00              SV Darmstadt
# 250462  28296964      DE 2017-07-29 13:30:00+00:00              SV Darmstadt
# 249926  28314571      DE 2017-07-29 13:30:00+00:00         Arminia Bielefeld
# 250458  28296960      DE 2017-07-29 13:30:00+00:00         Arminia Bielefeld
# 235119  28296087      DE 2017-08-20 13:30:00+00:00                  Freiburg
# 237605  28337304      DE 2017-08-20 13:30:00+00:00                  Freiburg
# 235121  28296098      DE 2017-08-20 16:00:00+00:00                 Mgladbach
# 237606  28337308      DE 2017-08-20 16:00:00+00:00                 Mgladbach
# 259027  28237531      IT 2017-05-22 18:45:00+00:00                   Pescara
# 260061  28225115      IT 2017-05-22 18:45:00+00:00                   Pescara
# 296551  28935077      IT 2018-10-20 13:00:00+00:00                      Roma
# 297484  28950596      IT 2018-10-20 13:00:00+00:00                      Roma
# 296552  28935078      IT 2018-10-20 16:00:00+00:00                  Juventus
# 297483  28950595      IT 2018-10-20 16:00:00+00:00                  Juventus
# 296553  28935079      IT 2018-10-20 18:30:00+00:00                   Udinese
# 297482  28950594      IT 2018-10-20 18:30:00+00:00                   Udinese
# 296554  28935081      IT 2018-10-21 10:30:00+00:00                 Frosinone
# 297789  28950611      IT 2018-10-21 10:30:00+00:00                 Frosinone
# 296560  28935093      IT 2018-10-21 13:00:00+00:00                   Bologna
# 297787  28950603      IT 2018-10-21 13:00:00+00:00                   Bologna
# 296555  28935083      IT 2018-10-21 13:00:00+00:00                    Chievo
# 297788  28950604      IT 2018-10-21 13:00:00+00:00                    Chievo
# 296556  28935084      IT 2018-10-21 13:00:00+00:00                     Parma
# 297786  28950601      IT 2018-10-21 13:00:00+00:00                     Parma
# 296557  28935085      IT 2018-10-21 16:00:00+00:00                Fiorentina
# 297790  28950612      IT 2018-10-21 16:00:00+00:00                Fiorentina
# 296558  28935086      IT 2018-10-21 18:30:00+00:00                     Inter
# 297998  28950600      IT 2018-10-21 18:30:00+00:00                     Inter
# 296568  28936824      IT 2018-10-27 13:00:00+00:00                  Atalanta
# 298576  28950840      IT 2018-10-27 13:00:00+00:00                  Atalanta
# 296570  28947883      IT 2018-10-28 11:30:00+00:00                  Sassuolo
# 298582  28950854      IT 2018-10-28 11:30:00+00:00                  Sassuolo
# 296571  28947884      IT 2018-10-28 14:00:00+00:00                  Cagliari
# 298580  28950849      IT 2018-10-28 14:00:00+00:00                  Cagliari
# 296573  28947887      IT 2018-10-28 14:00:00+00:00                     Genoa
# 298579  28950846      IT 2018-10-28 14:00:00+00:00                     Genoa
# 296572  28947885      IT 2018-10-28 14:00:00+00:00                      Spal
# 298581  28950852      IT 2018-10-28 14:00:00+00:00                      Spal
# 296574  28947888      IT 2018-10-28 17:00:00+00:00                  AC Milan
# 298578  28950844      IT 2018-10-28 17:00:00+00:00                  AC Milan
# 296575  28947890      IT 2018-10-28 19:30:00+00:00                    Napoli
# 298577  28950843      IT 2018-10-28 19:30:00+00:00                    Napoli
# 296576  28947892      IT 2018-10-29 19:30:00+00:00                     Lazio
# 298826  28950855      IT 2018-10-29 19:30:00+00:00                     Lazio
# 6416    28950704      IT 2018-10-31 19:30:00+00:00                  AC Milan
# 296595  28949925      IT 2018-10-31 19:30:00+00:00                  AC Milan
# 179883  27741676      IT 2016-04-02 13:00:00+00:00                  Cagliari
# 206249  27736708      IT 2016-04-02 13:00:00+00:00                  Cagliari
# 179873  27741671      IT 2016-04-02 13:00:00+00:00                    Latina
# 206250  27736710      IT 2016-04-02 13:00:00+00:00                    Latina
# 179881  27741675      IT 2016-04-02 13:00:00+00:00                   Pescara
# 206251  27736713      IT 2016-04-02 13:00:00+00:00                   Pescara
# 179869  27741669      IT 2016-04-02 13:00:00+00:00              Pro Vercelli
# 206252  27736714      IT 2016-04-02 13:00:00+00:00              Pro Vercelli
# 179877  27741673      IT 2016-04-02 13:00:00+00:00                   Trapani
# 206253  27736716      IT 2016-04-02 13:00:00+00:00                   Trapani
# 179875  27741672      IT 2016-04-02 13:00:00+00:00                   Vicenza
# 206254  27736717      IT 2016-04-02 13:00:00+00:00                   Vicenza
# 181865  27741677      IT 2016-04-03 15:30:00+00:00                    Novara
# 206255  27737191      IT 2016-04-03 15:30:00+00:00                    Novara
# 235425  28355919      PT 2017-08-28 19:00:00+00:00              Portimonense
# 236641  28352253      PT 2017-08-28 19:00:00+00:00              Portimonense
# 16690   29124376      PT 2019-02-15 20:30:00+00:00                   Rio Ave
# 16856   29112776      PT 2019-02-15 20:30:00+00:00                   Rio Ave
# 16623   29124642      PT 2019-02-16 15:30:00+00:00       CD Nacional Funchal
# 16982   29112779      PT 2019-02-16 15:30:00+00:00                  Nacional
# 16615   29124379      PT 2019-02-16 18:00:00+00:00                 Guimaraes
# 16983   29112780      PT 2019-02-16 18:00:00+00:00                 Guimaraes
# 16614   29124378      PT 2019-02-16 20:30:00+00:00                     Porto
# 16984   29112781      PT 2019-02-16 20:30:00+00:00                     Porto
# 187578  27853333      GB 2016-08-07 11:15:00+00:00             St Johnstone
# 187579  27853333      GB 2016-08-07 11:15:00+00:00              St Johnstone
# 237435  28296903      GB 2017-08-06 14:00:00+00:00                  Aberdeen
# 250794  28325198      GB 2017-08-06 14:00:00+00:00                  Aberdeen
# 245800  28062484      ES 2017-01-15 15:15:00+00:00                Celta Vigo
# 249034  28068811      ES 2017-01-15 15:15:00+00:00                Celta Vigo
# 245802  28062730      ES 2017-01-15 17:30:00+00:00            Sporting Gijon
# 249032  28068810      ES 2017-01-15 17:30:00+00:00            Sporting Gijon
# 234233  28341425      ES 2017-08-19 18:15:00+00:00                    Girona
# 234599  28316091      ES 2017-08-19 18:15:00+00:00                    Girona
# 294679  28718842      TR 2018-05-14 17:00:00+00:00               Kayserispor
# 294827  28722121      TR 2018-05-14 17:00:00+00:00               Kayserispor
# 16585   29111437      TR 2019-02-11 17:00:00+00:00                 Sivasspor
# 16590   29113344      TR 2019-02-11 17:00:00+00:00                 Sivasspor
# 16584   29111436      TR 2019-02-11 17:00:00+00:00                Ankaragucu
# 16589   29113338      TR 2019-02-11 17:00:00+00:00                Ankaragucu
# 18818   29154787      US 2019-03-02 23:00:00+00:00       Vancouver Whitecaps
# 27262   29135734      US 2019-03-02 23:00:00+00:00       Vancouver Whitecaps
# 10609   29402906      US 2019-08-12 02:00:00+00:00            Los Angeles FC
# 10651   29402904      US 2019-08-12 02:00:00+00:00            Los Angeles FC
#
#                   away_team                                      event_name  \
# 298208                Colon                                 Huracan v Colon
# 298363                Colon                                 Huracan v Colon
# 298217             Aldosivi                          River Plate v Aldosivi
# 298364             Aldosivi                          River Plate v Aldosivi
# 298216         Boca Juniors                Gimnasia La Plata v Boca Juniors
# 298365         Boca Juniors                Gimnasia La Plata v Boca Juniors
# 277185    Melbourne Victory              Newcastle Jets v Melbourne Victory
# 277186    Melbourne Victory              Newcastle Jets v Melbourne Victory
# 295910    Melbourne Victory              Newcastle Jets v Melbourne Victory
# 297231               Sydney                     Adelaide United v Sydney FC
# 297232               Sydney                        Adelaide United v Sydney
# 297744            Newcastle             Wellington Phoenix v Newcastle Jets
# 297745       Newcastle Jets             Wellington Phoenix v Newcastle Jets
# 19656     Wellington Poenix             Adelaide United v Wellington Poenix
# 22254    Wellington Phoenix            Adelaide United v Wellington Phoenix
# 16993                Sydney                     Wellington Phoenix v Sydney
# 18103                Sydney                     Wellington Phoenix v Sydney
# 17245           Perth Glory          Western Sydney Wanderers v Perth Glory
# 18394           Perth Glory          Western Sydney Wanderers v Perth Glory
# 35430             Newcastle  Central Coast Mariners v Newcastle United Jets
# 35432        Newcastle Jets         Central Coast Mariners v Newcastle Jets
# 31107             Newcastle                      Sydney FC v Newcastle Jets
# 31108        Newcastle Jets                      Sydney FC v Newcastle Jets
# 31690             Newcastle                 Western United v Newcastle Jets
# 31691        Newcastle Jets                 Western United v Newcastle Jets
# 226932               Gremio                               Coritiba v Gremio
# 227592               Gremio                               Coritiba v Gremio
# 226934               Santos                          Internacional v Santos
# 227655               Santos                          Internacional v Santos
# 147453     Shanghai Shenhua           Hangzhou Greentown v Shanghai Shenhua
# 150668     Shanghai Shenhua           Hangzhou Greentown v Shanghai Shenhua
# 147452        Guizhou Renhe                 Chongqing Lifan v Guizhou Renhe
# 150669        Guizhou Renhe                 Chongqing Lifan v Guizhou Renhe
# 10560          Guangzhou FC                    Beijing Guoan v Guangzhou FC
# 10561          Guangzhou FC                    Beijing Guoan v Guangzhou FC
# 233854         Huddersfield                         C Palace v Huddersfield
# 252420    Huddersfield Town              Crystal Palace v Huddersfield Town
# 234580             C Palace                            Liverpool v C Palace
# 252426       Crystal Palace                      Liverpool v Crystal Palace
# 235117            Newcastle                        Huddersfield v Newcastle
# 237604            Newcastle                        Huddersfield v Newcastle
# 235115              Chelsea                             Tottenham v Chelsea
# 237601              Chelsea                             Tottenham v Chelsea
# 235352              Everton                              Man City v Everton
# 237602              Everton                              Man City v Everton
# 262756            Tottenham                      Leicester City v Tottenham
# 264528            Tottenham                           Leicester v Tottenham
# 262758            Liverpool                          Stoke City v Liverpool
# 264612            Liverpool                               Stoke v Liverpool
# 239043              Burnley                             Leicester v Burnley
# 262760              Burnley                        Leicester City v Burnley
# 239045              Swansea                                 Stoke v Swansea
# 262762              Swansea                            Stoke City v Swansea
# 230438                 Lens                                 Le Havre v Lens
# 231062                 Lens                                 Le Havre v Lens
# 16586               Auxerre                                 Brest v Auxerre
# 19354               Auxerre                                 Brest v Auxerre
# 13354           Chateauroux                             Niort v Chateauroux
# 13399           Chateauroux                             Niort v Chateauroux
# 13348          Valenciennes                          Le Mans v Valenciennes
# 13393          Valenciennes                          Le Mans v Valenciennes
# 13355              Le Havre                         ESTAC Troyes v Le Havre
# 13400              Le Havre                         ESTAC Troyes v Le Havre
# 13352              Paris FC                                Rodez v Paris FC
# 13397              Paris FC                                Rodez v Paris FC
# 13351               Orleans                              Guingamp v Orleans
# 13396               Orleans                              Guingamp v Orleans
# 13350                  Caen                               AC Ajaccio v Caen
# 13395                  Caen                               AC Ajaccio v Caen
# 13353               Lorient                                 Nancy v Lorient
# 13398               Lorient                                 Nancy v Lorient
# 13349               Auxerre                               Sochaux v Auxerre
# 13394               Auxerre                               Sochaux v Auxerre
# 240981       Dynamo Dresden                       St Pauli v Dynamo Dresden
# 241680       Dynamo Dresden                       St Pauli v Dynamo Dresden
# 249924         Union Berlin                       Ingolstadt v Union Berlin
# 250460         Union Berlin                       Ingolstadt v Union Berlin
# 250290       Greuther Furth                   SV Darmstadt v Greuther Furth
# 250462       Greuther Furth                   SV Darmstadt v Greuther Furth
# 249926      Jahn Regensburg             Arminia Bielefeld v Jahn Regensburg
# 250458      Jahn Regensburg             Arminia Bielefeld v Jahn Regensburg
# 235119  Eintracht Frankfurt                  Freiburg v Eintracht Frankfurt
# 237605  Eintracht Frankfurt                  Freiburg v Eintracht Frankfurt
# 235121              FC Koln                             Mgladbach v FC Koln
# 237606              FC Koln                             Mgladbach v FC Koln
# 259027              Palermo                               Pescara v Palermo
# 260061              Palermo                               Pescara v Palermo
# 296551                 Spal                                     Roma v SPAL
# 297484                 Spal                                     Roma v SPAL
# 296552                Genoa                                Juventus v Genoa
# 297483                Genoa                                Juventus v Genoa
# 296553               Napoli                                Udinese v Napoli
# 297482               Napoli                                Udinese v Napoli
# 296554               Empoli                              Frosinone v Empoli
# 297789               Empoli                              Frosinone v Empoli
# 296560               Torino                                Bologna v Torino
# 297787               Torino                                Bologna v Torino
# 296555             Atalanta                               Chievo v Atalanta
# 297788             Atalanta                               Chievo v Atalanta
# 296556                Lazio                                   Parma v Lazio
# 297786                Lazio                                   Parma v Lazio
# 296557             Cagliari                           Fiorentina v Cagliari
# 297790             Cagliari                           Fiorentina v Cagliari
# 296558             AC Milan                                Inter v AC Milan
# 297998             AC Milan                                Inter v AC Milan
# 296568                Parma                                Atalanta v Parma
# 298576                Parma                                Atalanta v Parma
# 296570              Bologna                              Sassuolo v Bologna
# 298582              Bologna                              Sassuolo v Bologna
# 296571               Chievo                               Cagliari v Chievo
# 298580               Chievo                               Cagliari v Chievo
# 296573              Udinese                                 Genoa v Udinese
# 298579              Udinese                                 Genoa v Udinese
# 296572            Frosinone                                SPAL v Frosinone
# 298581            Frosinone                                SPAL v Frosinone
# 296574            Sampdoria                            AC Milan v Sampdoria
# 298578            Sampdoria                            AC Milan v Sampdoria
# 296575                 Roma                                   Napoli v Roma
# 298577                 Roma                                   Napoli v Roma
# 296576                Inter                                   Lazio v Inter
# 298826                Inter                                   Lazio v Inter
# 6416                  Genoa                                AC Milan v Genoa
# 296595                Genoa                                AC Milan v Genoa
# 179883               Spezia                               Cagliari v Spezia
# 206249               Spezia                               Cagliari v Spezia
# 179873             Avellino                               Latina v Avellino
# 206250             Avellino                               Latina v Avellino
# 179881                 Como                                  Pescara v Como
# 206251                 Como                                  Pescara v Como
# 179869               Modena                           Pro Vercelli v Modena
# 206252               Modena                           Pro Vercelli v Modena
# 179877              Brescia                               Trapani v Brescia
# 206253              Brescia                               Trapani v Brescia
# 179875              Livorno                               Vicenza v Livorno
# 206254              Livorno                               Vicenza v Livorno
# 181865          Salernitana                            Novara v Salernitana
# 206255          Salernitana                            Novara v Salernitana
# 235425             Maritimo                         Portimonense v Maritimo
# 236641             Maritimo                         Portimonense v Maritimo
# 16690           Santa Clara                           Rio Ave v Santa Clara
# 16856           Santa Clara                           Rio Ave v Santa Clara
# 16623              Feirense                  CD Nacional Funchal v Feirense
# 16982              Feirense                             Nacional v Feirense
# 16615          Portimonense                        Guimaraes v Portimonense
# 16983          Portimonense                        Guimaraes v Portimonense
# 16614               Setubal                                 Porto v Setubal
# 16984               Setubal                                 Porto v Setubal
# 187578             Aberdeen                         St Johnstone v Aberdeen
# 187579             Aberdeen                         St Johnstone v Aberdeen
# 237435             Hamilton                             Aberdeen v Hamilton
# 250794             Hamilton                             Aberdeen v Hamilton
# 245800               Alaves                             Celta Vigo v Alaves
# 249034               Alaves                             Celta Vigo v Alaves
# 245802                Eibar                          Sporting Gijon v Eibar
# 249032                Eibar                          Sporting Gijon v Eibar
# 234233      Atletico Madrid                        Girona v Atletico Madrid
# 234599      Atletico Madrid                        Girona v Atletico Madrid
# 294679     Akhisar Belediye                  Kayserispor v Akhisar Belediye
# 294827     Akhisar Bld Spor                  Kayserispor v Akhisar Bld Spor
# 16585      Akhisar Belediye                    Sivasspor v Akhisar Belediye
# 16590      Akhisar Belediye                    Sivasspor v Akhisar Belediye
# 16584             Kasimpasa                          Ankaragucu v Kasimpasa
# 16589             Kasimpasa                          Ankaragucu v Kasimpasa
# 18818         Minnesota Utd             Vancouver Whitecaps v Minnesota Utd
# 27262         Minnesota Utd             Vancouver Whitecaps v Minnesota Utd
# 10609    New York Red Bulls             Los Angeles FC v New York Red Bulls
# 10651    New York Red Bulls             Los Angeles FC v New York Red Bulls
#
#        country_caus
# 298208           AR
# 298363           AR
# 298217           AR
# 298364           AR
# 298216           AR
# 298365           AR
# 277185           AU
# 277186           AU
# 295910           AU
# 297231           AU
# 297232           AU
# 297744           AU
# 297745           AU
# 19656            AU
# 22254            AU
# 16993            AU
# 18103            AU
# 17245            AU
# 18394            AU
# 35430            AU
# 35432            AU
# 31107            AU
# 31108            AU
# 31690            AU
# 31691            AU
# 226932           BR
# 227592           BR
# 226934           BR
# 227655           BR
# 147453           CN
# 150668           CN
# 147452           CN
# 150669           CN
# 10560            CN
# 10561            CN
# 233854           GB
# 252420           GB
# 234580           GB
# 252426           GB
# 235117           GB
# 237604           GB
# 235115           GB
# 237601           GB
# 235352           GB
# 237602           GB
# 262756           GB
# 264528           GB
# 262758           GB
# 264612           GB
# 239043           GB
# 262760           GB
# 239045           GB
# 262762           GB
# 230438           FR
# 231062           FR
# 16586            FR
# 19354            FR
# 13354            FR
# 13399            FR
# 13348            FR
# 13393            FR
# 13355            FR
# 13400            FR
# 13352            FR
# 13397            FR
# 13351            FR
# 13396            FR
# 13350            FR
# 13395            FR
# 13353            FR
# 13398            FR
# 13349            FR
# 13394            FR
# 240981           DE
# 241680           DE
# 249924           DE
# 250460           DE
# 250290           DE
# 250462           DE
# 249926           DE
# 250458           DE
# 235119           DE
# 237605           DE
# 235121           DE
# 237606           DE
# 259027           IT
# 260061           IT
# 296551           IT
# 297484           IT
# 296552           IT
# 297483           IT
# 296553           IT
# 297482           IT
# 296554           IT
# 297789           IT
# 296560           IT
# 297787           IT
# 296555           IT
# 297788           IT
# 296556           IT
# 297786           IT
# 296557           IT
# 297790           IT
# 296558           IT
# 297998           IT
# 296568           IT
# 298576           IT
# 296570           IT
# 298582           IT
# 296571           IT
# 298580           IT
# 296573           IT
# 298579           IT
# 296572           IT
# 298581           IT
# 296574           IT
# 298578           IT
# 296575           IT
# 298577           IT
# 296576           IT
# 298826           IT
# 6416             IT
# 296595           IT
# 179883           IT
# 206249           IT
# 179873           IT
# 206250           IT
# 179881           IT
# 206251           IT
# 179869           IT
# 206252           IT
# 179877           IT
# 206253           IT
# 179875           IT
# 206254           IT
# 181865           IT
# 206255           IT
# 235425           PT
# 236641           PT
# 16690            PT
# 16856            PT
# 16623            PT
# 16982            PT
# 16615            PT
# 16983            PT
# 16614            PT
# 16984            PT
# 187578           GB
# 187579           GB
# 237435           GB
# 250794           GB
# 245800           ES
# 249034           ES
# 245802           ES
# 249032           ES
# 234233           ES
# 234599           ES
# 294679           TR
# 294827           TR
# 16585            TR
# 16590            TR
# 16584            TR
# 16589            TR
# 18818            US
# 27262            US
# 10609            US
# 10651            US

# %% [markdown]
# By inspecting team names, we conclude that even though in some cases there are differences in team names, the names are indeed correct and the plurality of event ids for these matches is not caused by an ambiguity in team names.
# There are also very few cases of more than one name variation for the same `event id` (e.g. `27853333`).
# Let us manually inspect the content of the full Betfair data files for a sample of these matches.

# %%
EVENT_ID_INDEX = -2
files_more_than_one_event_id = [file for file in matching_files if file.split('\\')[EVENT_ID_INDEX] in more_than_one_event_id['event_id'].values]

# %%
EVENT_ID_INDEX = -2
def get_filenames_for_event_id(event_id, filenames):
    return [file for file in filenames if file.split('\\')[EVENT_ID_INDEX] == event_id]

# %%
# display some filenames
for event_id in more_than_one_event_id['event_id'].iloc[:6]:
    print(get_filenames_for_event_id(event_id, files_more_than_one_event_id))
# Out:
# ['..\\data\\raw\\betfair\\xds_nfs\\hdfs_supreme\\BASIC\\2018\\Oct\\25\\28970987\\1.150185260.bz2']
# ['..\\data\\raw\\betfair\\xds_nfs\\hdfs_supreme\\BASIC\\2018\\Oct\\27\\28962339\\1.149749652.bz2']
# ['..\\data\\raw\\betfair\\xds_nfs\\hdfs_supreme\\BASIC\\2018\\Oct\\25\\28972910\\1.150186213.bz2']
# ['..\\data\\raw\\betfair\\xds_nfs\\hdfs_supreme\\BASIC\\2018\\Oct\\27\\28962340\\1.149749768.bz2']
# ['..\\data\\raw\\betfair\\xds_nfs\\hdfs_supreme\\BASIC\\2018\\Oct\\25\\28972909\\1.150186347.bz2']
# ['..\\data\\raw\\betfair\\xds_nfs\\hdfs_supreme\\BASIC\\2018\\Oct\\27\\28962342\\1.149749894.bz2']

# %% [markdown]
# By manually inspecting the content of the full Betfair data files for a sample of matches, we observe that for one of the `event id`s, the data file contains the relevant data, and the data file of the second event id is very limited, without prices, as if the market was set and then cancelled.
# As our objective with Betfair data is to get `in-play` prices, we check **all** data files for an active `in-play` market.

# %%
def check_in_play(bf_data_list):
    """
    Take a list of dictionaries from a Betfair data file and check if the market turns in-play.
    
    Parameter:
    bf_data_list(list): list of dictionaries from a Betfair data file.
    
    Return: Boolean (True if the market turns in-play).
    """
    in_play = False
    for record in bf_data_list:
        if record['mc']:
            for subrecord in record['mc']:
                if 'marketDefinition' in subrecord:
                    if subrecord['marketDefinition']['inPlay'] is True:
                        in_play = True
    return in_play

# %%
def get_event_ids_in_play(event_ids, files):
    """
    Take a list of lists of event ids (each list corresponds to a match),
    and return the event ids of matches with active in-play markets.
    
    Parameters:
    event_ids (list of lists): such as [['27433105'], ['27433103'], ['27433106', '27433114'], [], ...]
    files (list): list of filenames, such as ['xds_nfs\\hdfs_supreme\\BASIC\\2018\\Oct\\25\\28970987\\1.150185260.bz2', ...]
    
    Returns:
    event_ids_in_play (list of lists): subset of `event_ids` with only matches with active in-play markets.
    errors_event_ids_in_play (dic): eventual file reading errors.
    """
    event_ids_in_play = []
    errors_event_ids_in_play = {}
    for i, current_event_ids in tqdm(enumerate(event_ids)):
        current_event_ids_in_play = []
        for event_id in current_event_ids:
            # get filenames. Can be more than one per event id.
            files_of_event_id = get_filenames_for_event_id(event_id, files)
            # if in_play in any of files, event_id is relevant.
            for file in files_of_event_id:
                try:
                    bf_data_list = bz2_to_dict_list(file)
                    in_play = check_in_play(bf_data_list)
                    if (in_play and (event_id not in current_event_ids_in_play)):
                        current_event_ids_in_play.append(event_id)
                except Exception as e:
                    errors_event_ids_in_play[file] = e
                    bf_data_list = []
        event_ids_in_play.append(current_event_ids_in_play)
    return event_ids_in_play, errors_event_ids_in_play

# %%
event_ids_in_play, errors_event_ids_in_play = get_event_ids_in_play(event_ids, matching_files)
# Out:
# 36086it [3:59:14,  2.51it/s]

# %%
len(errors_event_ids_in_play)
# Out:
# 11

# %% [markdown]
# There is a very small number of files with invalid format issues or corrupted.
# Let us check the number of matches with `in-play` market data.

# %%
event_ids_in_play_len = [len(elt) for elt in event_ids_in_play]

# %%
pd.Series(event_ids_in_play_len).value_counts()
# Out:
# 1    31794
# 0     4292
# dtype: int64

# %%
pd.Series(event_ids_in_play_len).value_counts().loc[1] / len(event_ids_in_play_len)
# Out:
# 0.8810619076650225

# %% [markdown]
# As expected, each match has at most one compatible `event id`.
# 88% of matches have `in-play` market data.
# Let us flatten the `event_ids_in_play` list of lists and add an `event_id` column to the `footy` DataFrame.

# %%
event_ids_in_play_flat = []
for elt in event_ids_in_play:
    if len(elt) == 0:
        event_ids_in_play_flat.append(np.nan)
    elif len(elt) == 1:
        event_ids_in_play_flat.append(elt[0])

# %%
footy['event_id'] = event_ids_in_play_flat

# %%
footy
# Out:
#         timestamp            date_GMT    status      home_team_name  \
# 0      1430589600 2015-05-02 18:00:00  complete              Olimpo
# 1      1430597700 2015-05-02 20:15:00  complete   Gimnasia La Plata
# 2      1430601000 2015-05-02 21:10:00  complete         San Lorenzo
# 3      1430605800 2015-05-02 22:30:00  complete  Argentinos Juniors
# 4      1430608500 2015-05-02 23:15:00  complete         Racing Club
# ...           ...                 ...       ...                 ...
# 36081  1583632800 2020-03-08 02:00:00  complete     Colorado Rapids
# 36082  1583636400 2020-03-08 03:00:00  complete           LA Galaxy
# 36083  1583636400 2020-03-08 03:00:00  complete    Seattle Sounders
# 36084  1583708400 2020-03-08 23:00:00  complete    Portland Timbers
# 36085  1583721000 2020-03-09 02:30:00  complete      Los Angeles FC
#
#             away_team_name  home_team_goal_count  away_team_goal_count  \
# 0              Estudiantes                     0                     0
# 1        Newell's Old Boys                     0                     0
# 2          Vélez Sarsfield                     1                     0
# 3                 Aldosivi                     0                     1
# 4                    Lanús                     2                     0
# ...                    ...                   ...                   ...
# 36081         Orlando City                     2                     1
# 36082  Vancouver Whitecaps                     0                     1
# 36083        Columbus Crew                     1                     1
# 36084         Nashville SC                     1                     0
# 36085   Philadelphia Union                     3                     3
#
#       home_team_goal_timings away_team_goal_timings    country country_code  \
# 0                        NaN                    NaN  argentina           AR
# 1                        NaN                    NaN  argentina           AR
# 2                         83                    NaN  argentina           AR
# 3                        NaN                   45'1  argentina           AR
# 4                      72,90                    NaN  argentina           AR
# ...                      ...                    ...        ...          ...
# 36081                  64,90                     82        usa           US
# 36082                    NaN                     74        usa           US
# 36083                     79                     33        usa           US
# 36084                     12                    NaN        usa           US
# 36085               38,49,71               29,48,69        usa           US
#
#        event_id
# 0      27433105
# 1      27433103
# 2      27433106
# 3           NaN
# 4      27433114
# ...         ...
# 36081  29700007
# 36082  29700009
# 36083  29700008
# 36084  29713521
# 36085  29700023
#
# [36086 rows x 12 columns]

# %% [markdown]
# As a sanity check, verify that the `event id` per match is unique.

# %%
footy['event_id'].dropna().duplicated().any()
# Out:
# False

# %% [markdown]
# Export

# %%
FOOTY_EVENT_IDS_PATH = '../data/interim/footy_event_ids.csv'
footy.to_csv(FOOTY_EVENT_IDS_PATH, index=False)

# %% [markdown]
# ## check in-play market data availability per team

# %% [markdown]
# Get the `recall` of each team name, in the sense of: (number of relevant matches in footy data set) / (number of matches with in-play market data).
# Outliers per country should be checked for former names and aliases.
# The data below already reflects the result of this iterative process and the last manual checking version.

# %%
footy_recall = pd.concat([footy[['country_code', 'home_team_name', 'event_id']].rename(columns={'home_team_name': 'team_name'}),
                          footy[['country_code', 'away_team_name', 'event_id']].rename(columns={'away_team_name': 'team_name'})]).reset_index()

# %%
footy_recall['recall'] = footy_recall['event_id'].notna().astype(int)

# %% [markdown]
# Group by country and team name.

# %%
footy_recall_grouped = footy_recall.groupby(['country_code','team_name']).agg({'recall': ['mean', 'sum', 'count']})

# %% [markdown]
# Get totals per country.

# %%
footy_recall_grouped_countries = footy_recall.groupby(['country_code']).agg({'recall': ['mean', 'sum', 'count']})
new_cols = list(zip(footy_recall_grouped_countries.index.get_level_values(0), 
                    ['total_country'] * len(footy_recall_grouped_countries.index)))
footy_recall_grouped_countries.index = pd.MultiIndex.from_tuples(new_cols)

# %%
footy_recall_grouped_countries_totals = pd.concat([footy_recall_grouped, footy_recall_grouped_countries]).sort_index()

# %% [markdown]
# Flatten column names, so we can use `style.format` easily.

# %%
footy_recall_grouped_countries_totals.columns = [' '.join(col).strip() for col in footy_recall_grouped_countries_totals.columns.values]

# %% [markdown]
# Set `pandas` to display all rows, so we can inspect all team names.

# %%
pd.set_option('display.max_rows', None)

# %%
footy_recall_grouped_countries_totals.style.format(precision=2).background_gradient(subset='recall mean')
# Out:
# <style type="text/css">
# #T_09679_row0_col0, #T_09679_row279_col0, #T_09679_row313_col0, #T_09679_row376_col0, #T_09679_row396_col0, #T_09679_row403_col0, #T_09679_row447_col0, #T_09679_row458_col0 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_09679_row1_col0, #T_09679_row57_col0 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_09679_row2_col0, #T_09679_row98_col0, #T_09679_row165_col0, #T_09679_row168_col0, #T_09679_row181_col0, #T_09679_row327_col0, #T_09679_row348_col0 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_09679_row3_col0, #T_09679_row149_col0, #T_09679_row394_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_09679_row4_col0, #T_09679_row171_col0 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_09679_row5_col0, #T_09679_row74_col0, #T_09679_row76_col0, #T_09679_row114_col0, #T_09679_row457_col0, #T_09679_row479_col0, #T_09679_row532_col0 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_09679_row6_col0, #T_09679_row15_col0, #T_09679_row75_col0, #T_09679_row469_col0 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_09679_row7_col0, #T_09679_row25_col0, #T_09679_row193_col0, #T_09679_row202_col0, #T_09679_row528_col0, #T_09679_row545_col0 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_09679_row8_col0, #T_09679_row106_col0, #T_09679_row111_col0, #T_09679_row116_col0, #T_09679_row129_col0, #T_09679_row139_col0, #T_09679_row146_col0, #T_09679_row203_col0, #T_09679_row250_col0, #T_09679_row256_col0, #T_09679_row292_col0, #T_09679_row299_col0, #T_09679_row303_col0, #T_09679_row309_col0, #T_09679_row343_col0, #T_09679_row387_col0, #T_09679_row409_col0, #T_09679_row437_col0, #T_09679_row505_col0, #T_09679_row509_col0 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_09679_row9_col0 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_09679_row10_col0, #T_09679_row159_col0, #T_09679_row162_col0, #T_09679_row190_col0, #T_09679_row225_col0, #T_09679_row228_col0, #T_09679_row232_col0, #T_09679_row236_col0, #T_09679_row245_col0, #T_09679_row249_col0, #T_09679_row451_col0, #T_09679_row468_col0, #T_09679_row471_col0, #T_09679_row489_col0 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_09679_row11_col0, #T_09679_row16_col0, #T_09679_row20_col0, #T_09679_row51_col0, #T_09679_row151_col0, #T_09679_row157_col0, #T_09679_row173_col0, #T_09679_row375_col0, #T_09679_row388_col0, #T_09679_row478_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_09679_row12_col0, #T_09679_row156_col0, #T_09679_row227_col0, #T_09679_row243_col0, #T_09679_row374_col0, #T_09679_row377_col0, #T_09679_row381_col0, #T_09679_row385_col0, #T_09679_row526_col0 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_09679_row13_col0, #T_09679_row36_col0, #T_09679_row79_col0, #T_09679_row542_col0 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_09679_row14_col0, #T_09679_row17_col0, #T_09679_row59_col0, #T_09679_row109_col0, #T_09679_row127_col0, #T_09679_row135_col0, #T_09679_row349_col0, #T_09679_row350_col0, #T_09679_row363_col0, #T_09679_row366_col0, #T_09679_row491_col0 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_09679_row18_col0, #T_09679_row23_col0, #T_09679_row105_col0, #T_09679_row126_col0, #T_09679_row167_col0, #T_09679_row180_col0, #T_09679_row324_col0, #T_09679_row416_col0, #T_09679_row449_col0, #T_09679_row487_col0, #T_09679_row495_col0, #T_09679_row498_col0, #T_09679_row499_col0, #T_09679_row501_col0, #T_09679_row516_col0, #T_09679_row521_col0 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_09679_row19_col0, #T_09679_row265_col0, #T_09679_row291_col0, #T_09679_row322_col0, #T_09679_row467_col0, #T_09679_row506_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_09679_row21_col0 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_09679_row22_col0, #T_09679_row150_col0, #T_09679_row220_col0, #T_09679_row229_col0, #T_09679_row242_col0, #T_09679_row334_col0, #T_09679_row346_col0, #T_09679_row347_col0, #T_09679_row361_col0, #T_09679_row390_col0, #T_09679_row455_col0, #T_09679_row464_col0, #T_09679_row519_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_09679_row24_col0 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_09679_row26_col0, #T_09679_row64_col0, #T_09679_row67_col0, #T_09679_row153_col0, #T_09679_row154_col0, #T_09679_row172_col0, #T_09679_row177_col0, #T_09679_row191_col0, #T_09679_row200_col0, #T_09679_row204_col0, #T_09679_row339_col0, #T_09679_row354_col0, #T_09679_row551_col0, #T_09679_row552_col0 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_09679_row27_col0, #T_09679_row199_col0, #T_09679_row247_col0, #T_09679_row321_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_09679_row28_col0, #T_09679_row34_col0, #T_09679_row55_col0, #T_09679_row208_col0, #T_09679_row231_col0, #T_09679_row453_col0, #T_09679_row466_col0, #T_09679_row538_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_09679_row29_col0 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_09679_row30_col0, #T_09679_row58_col0, #T_09679_row77_col0, #T_09679_row336_col0, #T_09679_row470_col0, #T_09679_row544_col0 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_09679_row31_col0 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_09679_row32_col0, #T_09679_row547_col0 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_09679_row33_col0, #T_09679_row534_col0 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_09679_row35_col0, #T_09679_row164_col0, #T_09679_row235_col0, #T_09679_row454_col0, #T_09679_row461_col0, #T_09679_row472_col0, #T_09679_row473_col0, #T_09679_row524_col0, #T_09679_row549_col0, #T_09679_row553_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_09679_row37_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_09679_row38_col0, #T_09679_row80_col0 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_09679_row39_col0 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_09679_row40_col0 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_09679_row41_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_09679_row42_col0, #T_09679_row155_col0, #T_09679_row163_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_09679_row43_col0 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_09679_row44_col0 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_09679_row45_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_09679_row46_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_09679_row47_col0, #T_09679_row133_col0, #T_09679_row147_col0, #T_09679_row289_col0, #T_09679_row365_col0, #T_09679_row379_col0, #T_09679_row406_col0, #T_09679_row420_col0, #T_09679_row440_col0, #T_09679_row481_col0, #T_09679_row508_col0, #T_09679_row513_col0, #T_09679_row536_col0, #T_09679_row541_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_09679_row48_col0 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_09679_row49_col0, #T_09679_row53_col0, #T_09679_row69_col0, #T_09679_row186_col0, #T_09679_row537_col0, #T_09679_row554_col0 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_09679_row50_col0, #T_09679_row71_col0 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_09679_row52_col0, #T_09679_row152_col0, #T_09679_row189_col0, #T_09679_row192_col0, #T_09679_row201_col0, #T_09679_row477_col0, #T_09679_row492_col0 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_09679_row54_col0, #T_09679_row102_col0 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_09679_row56_col0, #T_09679_row65_col0, #T_09679_row137_col0, #T_09679_row215_col0, #T_09679_row216_col0, #T_09679_row230_col0, #T_09679_row273_col0, #T_09679_row274_col0, #T_09679_row345_col0, #T_09679_row369_col0, #T_09679_row402_col0, #T_09679_row441_col0, #T_09679_row483_col0, #T_09679_row511_col0 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_09679_row60_col0, #T_09679_row101_col0, #T_09679_row217_col0, #T_09679_row238_col0, #T_09679_row482_col0 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_09679_row61_col0, #T_09679_row62_col0, #T_09679_row2

# %% [markdown]
# Team names with low-ish `in-play data-wise recalls` were checked.
# In some cases, former names and aliases were found.
# The remaining team names with low-ish `in-play data-wise recalls` are from less traditional leagues and/or have less matches.

# %%
RECALL_EXAMPLE_THRESHOLD = .65
footy_recall_grouped_countries_totals[
    footy_recall_grouped_countries_totals['recall mean'] < RECALL_EXAMPLE_THRESHOLD
].style.format(precision=2).background_gradient(subset='recall mean')
# Out:
# <style type="text/css">
# #T_e620e_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e620e_row1_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_e620e_row2_col0 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_e620e_row3_col0 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_e620e_row4_col0 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_e620e_row5_col0 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_e620e_row6_col0 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_e620e_row7_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e620e_row8_col0 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_e620e_row9_col0 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_e620e_row10_col0 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e620e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e620e_level0_col0" class="col_heading level0 col0" >recall mean</th>
#       <th id="T_e620e_level0_col1" class="col_heading level0 col1" >recall sum</th>
#       <th id="T_e620e_level0_col2" class="col_heading level0 col2" >recall count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country_code</th>
#       <th class="index_name level1" >team_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e620e_level0_row0" class="row_heading level0 row0" >AR</th>
#       <th id="T_e620e_level1_row0" class="row_heading level1 row0" >San Martín Tucumán</th>
#       <td id="T_e620e_row0_col0" class="data row0 col0" >0.64</td>
#       <td id="T_e620e_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_e620e_row0_col2" class="data row0 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level0_row1" class="row_heading level0 row1" rowspan="3">AU</th>
#       <th id="T_e620e_level1_row1" class="row_heading level1 row1" >Adelaide United</th>
#       <td id="T_e620e_row1_col0" class="data row1 col0" >0.63</td>
#       <td id="T_e620e_row1_col1" class="data row1 col1" >85</td>
#       <td id="T_e620e_row1_col2" class="data row1 col2" >134</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level1_row2" class="row_heading level1 row2" >Wellington Phoenix</th>
#       <td id="T_e620e_row2_col0" class="data row2 col0" >0.64</td>
#       <td id="T_e620e_row2_col1" class="data row2 col1" >82</td>
#       <td id="T_e620e_row2_col2" class="data row2 col2" >129</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level1_row3" class="row_heading level1 row3" >Western Sydney Wanderers</th>
#       <td id="T_e620e_row3_col0" class="data row3 col0" >0.63</td>
#       <td id="T_e620e_row3_col1" class="data row3 col1" >83</td>
#       <td id="T_e620e_row3_col2" class="data row3 col2" >132</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level0_row4" class="row_heading level0 row4" rowspan="7">CN</th>
#       <th id="T_e620e_level1_row4" class="row_heading level1 row4" >Beijing Renhe</th>
#       <td id="T_e620e_row4_col0" class="data row4 col0" >0.54</td>
#       <td id="T_e620e_row4_col1" class="data row4 col1" >45</td>
#       <td id="T_e620e_row4_col2" class="data row4 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level1_row5" class="row_heading level1 row5" >Changchun Yatai</th>
#       <td id="T_e620e_row5_col0" class="data row5 col0" >0.60</td>
#       <td id="T_e620e_row5_col1" class="data row5 col1" >68</td>
#       <td id="T_e620e_row5_col2" class="data row5 col2" >114</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level1_row6" class="row_heading level1 row6" >Dalian Yifang</th>
#       <td id="T_e620e_row6_col0" class="data row6 col0" >0.43</td>
#       <td id="T_e620e_row6_col1" class="data row6 col1" >26</td>
#       <td id="T_e620e_row6_col2" class="data row6 col2" >60</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level1_row7" class="row_heading level1 row7" >Guizhou Zhicheng</th>
#       <td id="T_e620e_row7_col0" class="data row7 col0" >0.40</td>
#       <td id="T_e620e_row7_col1" class="data row7 col1" >24</td>
#       <td id="T_e620e_row7_col2" class="data row7 col2" >60</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level1_row8" class="row_heading level1 row8" >Jiangsu Suning</th>
#       <td id="T_e620e_row8_col0" class="data row8 col0" >0.60</td>
#       <td id="T_e620e_row8_col1" class="data row8 col1" >86</td>
#       <td id="T_e620e_row8_col2" class="data row8 col2" >143</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level1_row9" class="row_heading level1 row9" >Tianjin Quanjian</th>
#       <td id="T_e620e_row9_col0" class="data row9 col0" >0.60</td>
#       <td id="T_e620e_row9_col1" class="data row9 col1" >54</td>
#       <td id="T_e620e_row9_col2" class="data row9 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_e620e_level1_row10" class="row_heading level1 row10" >Tianjin Teda</th>
#       <td id="T_e620e_row10_col0" class="data row10 col0" >0.53</td>
#       <td id="T_e620e_row10_col1" class="data row10 col1" >76</td>
#       <td id="T_e620e_row10_col2" class="data row10 col2" >143</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The team names may be considered validated and the relevant `event id`s have been fetched.
